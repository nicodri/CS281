# %%
import sys, re, time, string
import numpy as n
from scipy.special import gammaln, psi

n.random.seed(100000001)
meanchangethresh = 0.001

def dirichlet_expectation(alpha):
    """
    For a vector theta ~ Dir(alpha), computes E[log(theta)] given alpha.
    """
    if (len(alpha.shape) == 1):
        return(psi(alpha) - psi(n.sum(alpha)))
    return(psi(alpha) - psi(n.sum(alpha, 1))[:, n.newaxis])

def parse_doc_list(docs, vocab):
    """
    Parse a document into a list of word ids and a list of counts,
    or parse a set of documents into two lists of lists of word ids
    and counts.

    Arguments: 
    docs:  List of D documents. Each document must be represented as
           a single string. (Word order is unimportant.) Any
           words not in the vocabulary will be ignored.
    vocab: Dictionary mapping from words to integer ids.

    Returns a pair of lists of lists. 

    The first, wordids, says what vocabulary tokens are present in
    each document. wordids[i][j] gives the jth unique token present in
    document i. (Don't count on these tokens being in any particular
    order.)

    The second, wordcts, says how many times each vocabulary token is
    present. wordcts[i][j] is the number of times that the token given
    by wordids[i][j] appears in document i.
    """
    if (type(docs).__name__ == 'str'):
        temp = list()
        temp.append(docs)
        docs = temp

    D = len(docs)
    
    wordids = list()
    wordcts = list()
    for d in range(0, D):
        docs[d] = docs[d].lower()
        docs[d] = re.sub(r'-', ' ', docs[d])
        docs[d] = re.sub(r'[^a-z ]', '', docs[d])
        docs[d] = re.sub(r' +', ' ', docs[d])
        words = string.split(docs[d])
        ddict = dict()
        for word in words:
            if (word in vocab):
                wordtoken = vocab[word]
                if (not wordtoken in ddict):
                    ddict[wordtoken] = 0
                ddict[wordtoken] += 1
        wordids.append(ddict.keys())
        wordcts.append(ddict.values())

    return((wordids, wordcts))

class OnlineLDA:
    """
    Implements online VB for LDA as described in (Hoffman et al. 2010).
    """

    def __init__(self, vocab, K, D, alpha, eta, tau0, kappa):
        """
        Arguments:
        K: Number of topics
        vocab: A set of words to recognize. When analyzing documents, any word
           not in this set will be ignored.
        D: Total number of documents in the population. For a fixed corpus,
           this is the size of the corpus. In the truly online setting, this
           can be an estimate of the maximum number of documents that
           could ever be seen.
        alpha: Hyperparameter for prior on weight vectors theta
        eta: Hyperparameter for prior on topics beta
        tau0: A (positive) learning parameter that downweights early iterations
        kappa: Learning rate: exponential decay rate---should be between
             (0.5, 1.0] to guarantee asymptotic convergence.

        Note that if you pass the same set of D documents in every time and
        set kappa=0 this class can also be used to do batch VB.
        """
        self._vocab = dict()
        for word in vocab:
            word = word.lower()
            word = re.sub(r'[^a-z]', '', word)
            self._vocab[word] = len(self._vocab)

        self._K = K
        self._W = len(self._vocab)
        self._D = D
        self._alpha = alpha
        self._eta = eta
        self._tau0 = tau0 + 1
        self._kappa = kappa
        self._updatect = 0

        # Initialize the variational distribution q(beta|lambda)
        self._lambda = 1*n.random.gamma(100., 1./100., (self._K, self._W))
        self._Elogbeta = dirichlet_expectation(self._lambda)
        self._expElogbeta = n.exp(self._Elogbeta)

    def do_e_step(self, docs):
        """
        Given a mini-batch of documents, estimates the parameters
        gamma controlling the variational distribution over the topic
        weights for each document in the mini-batch.

        Arguments:
        docs:  List of D documents. Each document must be represented
               as a string. (Word order is unimportant.) Any
               words not in the vocabulary will be ignored.

        Returns a tuple containing the estimated values of gamma,
        as well as sufficient statistics needed to update lambda.
        """
        # This is to handle the case where someone just hands us a single
        # document, not in a list.
        if (type(docs).__name__ == 'string'):
            temp = list()
            temp.append(docs)
            docs = temp

        (wordids, wordcts) = parse_doc_list(docs, self._vocab)
        batchD = len(docs)

        # Initialize the variational distribution q(theta|gamma) for
        # the mini-batch
        gamma = 1*n.random.gamma(100., 1./100., (batchD, self._K))
        Elogtheta = dirichlet_expectation(gamma)
        expElogtheta = n.exp(Elogtheta)

        sstats = n.zeros(self._lambda.shape)
        # Now, for each document d update that document's gamma and phi
        it = 0
        meanchange = 0
        for d in range(0, batchD):
            # These are mostly just shorthand (but might help cache locality)
            ids = wordids[d]
            cts = wordcts[d]
            gammad = gamma[d, :]
            Elogthetad = Elogtheta[d, :]
            expElogthetad = expElogtheta[d, :]
            expElogbetad = self._expElogbeta[:, ids]
            # The optimal phi_{dwk} is proportional to 
            # expElogthetad_k * expElogbetad_w. phinorm is the normalizer.
            phinorm = n.dot(expElogthetad, expElogbetad) + 1e-100
            # Iterate between gamma and phi until convergence
            for it in range(0, 100):
                lastgamma = gammad
                # We represent phi implicitly to save memory and time.
                # Substituting the value of the optimal phi back into
                # the update for gamma gives this update. Cf. Lee&Seung 2001.
                gammad = self._alpha + expElogthetad * \
                    n.dot(cts / phinorm, expElogbetad.T)
                Elogthetad = dirichlet_expectation(gammad)
                expElogthetad = n.exp(Elogthetad)
                phinorm = n.dot(expElogthetad, expElogbetad) + 1e-100
                # If gamma hasn't changed much, we're done.
                meanchange = n.mean(abs(gammad - lastgamma))
                if (meanchange < meanchangethresh):
                    break
            gamma[d, :] = gammad
            # Contribution of document d to the expected sufficient
            # statistics for the M step.
            sstats[:, ids] += n.outer(expElogthetad.T, cts/phinorm)

        # This step finishes computing the sufficient statistics for the
        # M step, so that
        # sstats[k, w] = \sum_d n_{dw} * phi_{dwk} 
        # = \sum_d n_{dw} * exp{Elogtheta_{dk} + Elogbeta_{kw}} / phinorm_{dw}.
        sstats = sstats * self._expElogbeta

        return((gamma, sstats))

    def update_lambda(self, docs):
        """
        First does an E step on the mini-batch given in wordids and
        wordcts, then uses the result of that E step to update the
        variational parameter matrix lambda.

        Arguments:
        docs:  List of D documents. Each document must be represented
               as a string. (Word order is unimportant.) Any
               words not in the vocabulary will be ignored.

        Returns gamma, the parameters to the variational distribution
        over the topic weights theta for the documents analyzed in this
        update.

        Also returns an estimate of the variational bound for the
        entire corpus for the OLD setting of lambda based on the
        documents passed in. This can be used as a (possibly very
        noisy) estimate of held-out likelihood.
        """

        # rhot will be between 0 and 1, and says how much to weight
        # the information we got from this mini-batch.
        rhot = pow(self._tau0 + self._updatect, -self._kappa)
        self._rhot = rhot
        # Do an E step to update gamma, phi | lambda for this
        # mini-batch. This also returns the information about phi that
        # we need to update lambda.
        (gamma, sstats) = self.do_e_step(docs)
        # Estimate held-out likelihood for current values of lambda.
        bound = self.approx_bound(docs, gamma)
        # Update lambda based on documents.
        self._lambda = self._lambda * (1-rhot) + \
            rhot * (self._eta + self._D * sstats / len(docs))
        self._Elogbeta = dirichlet_expectation(self._lambda)
        self._expElogbeta = n.exp(self._Elogbeta)
        self._updatect += 1

        return(gamma, bound)

    def approx_bound(self, docs, gamma):
        """
        Estimates the variational bound over *all documents* using only
        the documents passed in as "docs." gamma is the set of parameters
        to the variational distribution q(theta) corresponding to the
        set of documents passed in.

        The output of this function is going to be noisy, but can be
        useful for assessing convergence.
        """

        # This is to handle the case where someone just hands us a single
        # document, not in a list.
        if (type(docs).__name__ == 'string'):
            temp = list()
            temp.append(docs)
            docs = temp

        (wordids, wordcts) = parse_doc_list(docs, self._vocab)
        batchD = len(docs)

        score = 0
        Elogtheta = dirichlet_expectation(gamma)
        expElogtheta = n.exp(Elogtheta)

        # E[log p(docs | theta, beta)]
        for d in range(0, batchD):
            gammad = gamma[d, :]
            ids = wordids[d]
            cts = n.array(wordcts[d])
            phinorm = n.zeros(len(ids))
            for i in range(0, len(ids)):
                temp = Elogtheta[d, :] + self._Elogbeta[:, ids[i]]
                tmax = max(temp)
                phinorm[i] = n.log(sum(n.exp(temp - tmax))) + tmax
            score += n.sum(cts * phinorm)
#             oldphinorm = phinorm
#             phinorm = n.dot(expElogtheta[d, :], self._expElogbeta[:, ids])
#             print oldphinorm
#             print n.log(phinorm)
#             score += n.sum(cts * n.log(phinorm))

        # E[log p(theta | alpha) - log q(theta | gamma)]
        score += n.sum((self._alpha - gamma)*Elogtheta)
        score += n.sum(gammaln(gamma) - gammaln(self._alpha))
        score += sum(gammaln(self._alpha*self._K) - gammaln(n.sum(gamma, 1)))

        # Compensate for the subsampling of the population of documents
        score = score * self._D / len(docs)

        # E[log p(beta | eta) - log q (beta | lambda)]
        score = score + n.sum((self._eta-self._lambda)*self._Elogbeta)
        score = score + n.sum(gammaln(self._lambda) - gammaln(self._eta))
        score = score + n.sum(gammaln(self._eta*self._W) - 
                              gammaln(n.sum(self._lambda, 1)))

        return(score)

# %%
# The number of documents to analyze each iteration
batchsize = 50
# The total number of documents in Wikipedia
D = 3800
# The number of topics
K = 70

# %%
vocab = n.load('temp/lv_vocab10.npy')

# %%
W = len(vocab)

# %%
olda = OnlineLDA(vocab, K, D, 1./K, 1./K, 1024., 0.7)

# %%
sys.argv
# Out:
# ['/Users/virgileaudi/anaconda/lib/python2.7/site-packages/IPython/kernel/__main__.py',
#  '-f',
#  '/Users/virgileaudi/.ipython/profile_default/security/kernel-b4b96b25-6d05-499d-b714-5b991410a4cd.json',
#  '--profile-dir',
#  '/Users/virgileaudi/.ipython/profile_default']

# %%
documentstoanalyze = int(D/batchsize)
documentstoanalyze
# Out:
# 76

# %%
import json
with open('../Zipped_data_LV/lasvegas_word_adjective.json', 'r') as fp:
    lv_wadj = json.load(fp)

# %%
docsetbig = [] 
articlenamesbig = []

for k in lv_wadj.keys()[:3800]:
    docsetbig.append(" ".join(lv_wadj[k][0][0]))
    articlenamesbig.append(k)

# %%
len(docsetbig)
# Out:
# 3800

# %%
docsetbig = n.split(n.array(docsetbig),76)
articlenamesbig = n.split(n.array(docsetbig),76)

# %%
docsetbig[0][1]
# Out:
# u'dining choice spanish tapas sangria star half star reservation night bar place regular stool service food bit mouth sister cocktail day flavor signature fry bit meal tapas cuisine vegan blood mojitos server key persona tomato soup patio red smoker tapas place street parallel strip food couple sangrias bit fun person racket star diner time tapas total douche fest tittie bitch loser friend place visitor spot eat option entry sangrium fruit shit wine herb aioli meal tapas date almond wine reduction cheese bravas potato aioli kind meat tapa goody table tapas state place rate place time night hour half wing heating lamp bread type spread olife ceviche shrimp chip cannelloni goat cheese tomato sauce surprise hit goat cheese lover chop wine reduction sauteed lentil veggies bit bang buck filet grouper herb lemon garlic piece flavor pulpo asado octopus potato tomato banana nutella sandwich sauce party pitcher passion fruit food star rating atmosphere tapas time reservation evening friday pm pm appetizer plate date albondiga tortilla espanola location hotel car bar tight location music band food departure standard buffet tapas bar laugh way friend pro drink variety choice menu wine sangria empanada duck roll plaza restaurant wait alternative paella thing tapas bar bruschetta food service tapas calamari octopus fear factor food scene fashion idea table father mohawk baby mohawk lot hair strip riff raff ceviche snapper stuffed date canneloni tuna carpaccio shrimp garlic cream chorizo clam empanadilla skewer beef experience fine restaurant service price guest vegas tapas pitcher sangria music evening strip bunch newbies wine ceviche snapper boquerone white toast pepper almond date bacon firefly fry merguez lamb sausage tender lamb chop la diabla extrodinary banana nutella sandwich place date place music playing background seating place tapas bar evening crowd halter slack group family table outside patio waiter basket crostinis olife sweet butter mojito blood orange selection bar fig bacon wine reduction tuna tartar vegas restaurant place tourist chill strip place sangrias kind tapas variety kind food food mini burger beef tenderloin skewer rib dish course dessert banana hazelnut chocolate story drink food price check tapas restaurant strip friend boyfriend friend mojito strip casino air sound slot machine bell food sangrium d lish u atmosphere music vibe place sister door restaurant sequel door way friend money way fun share bar bar ass martini sport atmosphere wall wall person atmosphere ambiance food time day atmosphere drink dining choice spanish tapas star half star reservation night alternative strip restaurant club crowd street cab ride strip food hip atmosphere crowd tapas bar laugh way friend restaurant sequel door way friend money way fun share bar bar ass martini sport atmosphere wall wall person review crowdedness noise level seat table poop stuff minute dining partner seat bar pitcher sangrium share sangria variety wine wine wine light waiter selection filet mignon slider brie la diabla chicken mushroom sauce shrimp brie tomato food experience sangria tapas person spot boot tapas restaurant course mushroom mushroom family bistro review calamari dish review time restaurant look menu order menu dish taste restaurant hangout atmosphere food favorite course sangrium food atmosphere hour place atmosphere location music staff land booby dish ingredient light sangria bit tooo chunk fruit stuffed date bacon think prosciutto slider ambiance kind middle parking lot greenery dining sidewalk passer by kind guess hotel middle parking lot point ambiance waiter kind talk menu bit guess check place place sangrias nightspot sangrium tapas person bit attention dinner time party pitcher sangria filet mignon slider yum dessert service place party friend off strip food tuna ceviche sangrium band person crowd fun food music place strip fine filet mignon slider hamburger deal seasoning sangria place food staff try night place favorite secret reser ...

# %%
for iteration in range(0, documentstoanalyze):
    # Download some articles
    (docset, articlenames) = (docsetbig[iteration],articlenamesbig[iteration])
    # Give them to online LDA
    (gamma, bound) = olda.update_lambda(docset)        
    # Compute an estimate of held-out perplexity
    (wordids, wordcts) = parse_doc_list(docset, olda._vocab)
    perwordbound = bound * len(docset) / (D * sum(map(sum, wordcts)))
    print '%d:  rho_t = %f,  held-out perplexity estimate = %f' % (iteration, olda._rhot, n.exp(-perwordbound))
# Out:
# 0:  rho_t = 0.007807,  held-out perplexity estimate = 23594.791181
# 1:  rho_t = 0.007802,  held-out perplexity estimate = 2661.271950
# 2:  rho_t = 0.007797,  held-out perplexity estimate = 1805.509863
# 3:  rho_t = 0.007791,  held-out perplexity estimate = 1166.218632
# 4:  rho_t = 0.007786,  held-out perplexity estimate = 1064.972462
# 5:  rho_t = 0.007781,  held-out perplexity estimate = 1389.960396
# 6:  rho_t = 0.007775,  held-out perplexity estimate = 1198.478492
# 7:  rho_t = 0.007770,  held-out perplexity estimate = 1197.820761
# 8:  rho_t = 0.007765,  held-out perplexity estimate = 1063.490900
# 9:  rho_t = 0.007760,  held-out perplexity estimate = 1194.616418
# 10:  rho_t = 0.007754,  held-out perplexity estimate = 1214.583460
# 11:  rho_t = 0.007749,  held-out perplexity estimate = 1020.797582
# 12:  rho_t = 0.007744,  held-out perplexity estimate = 1056.592362
# 13:  rho_t = 0.007739,  held-out perplexity estimate = 995.408728
# 14:  rho_t = 0.007733,  held-out perplexity estimate = 1064.911825
# 15:  rho_t = 0.007728,  held-out perplexity estimate = 1032.525527
# 16:  rho_t = 0.007723,  held-out perplexity estimate = 1136.211847
# 17:  rho_t = 0.007718,  held-out perplexity estimate = 967.603725
# 18:  rho_t = 0.007713,  held-out perplexity estimate = 1208.212001
# 19:  rho_t = 0.007707,  held-out perplexity estimate = 1053.488715
# 20:  rho_t = 0.007702,  held-out perplexity estimate = 1059.026156
# 21:  rho_t = 0.007697,  held-out perplexity estimate = 965.631867
# 22:  rho_t = 0.007692,  held-out perplexity estimate = 1062.307816
# 23:  rho_t = 0.007687,  held-out perplexity estimate = 1159.613238
# 24:  rho_t = 0.007682,  held-out perplexity estimate = 1414.100901
# 25:  rho_t = 0.007677,  held-out perplexity estimate = 1125.532483
# 26:  rho_t = 0.007671,  held-out perplexity estimate = 1015.103304
# 27:  rho_t = 0.007666,  held-out perplexity estimate = 854.364610
# 28:  rho_t = 0.007661,  held-out perplexity estimate = 1113.361358
# 29:  rho_t = 0.007656,  held-out perplexity estimate = 1006.545343
# 30:  rho_t = 0.007651,  held-out perplexity estimate = 1416.436508
# 31:  rho_t = 0.007646,  held-out perplexity estimate = 890.539447
# 32:  rho_t = 0.007641,  held-out perplexity estimate = 1061.337488
# 33:  rho_t = 0.007636,  held-out perplexity estimate = 838.051758
# 34:  rho_t = 0.007631,  held-out perplexity estimate = 1137.472406
# 35:  rho_t = 0.007626,  held-out perplexity estimate = 1230.078715
# 36:  rho_t = 0.007621,  held-out perplexity estimate = 931.952127
# 37:  rho_t = 0.007616,  held-out perplexity estimate = 1173.004463
# 38:  rho_t = 0.007611,  held-out perplexity estimate = 1384.096695
# 39:  rho_t = 0.007606,  held-out perplexity estimate = 902.523224
# 40:  rho_t = 0.007601,  held-out perplexity estimate = 1009.801544
# 41:  rho_t = 0.007596,  held-out perplexity estimate = 1009.428347
# 42:  rho_t = 0.007591,  held-out perplexity estimate = 1262.420522
# 43:  rho_t = 0.007586,  held-out perplexity estimate = 1073.989246
# 44:  rho_t = 0.007581,  held-out perplexity estimate = 833.020112
# 45:  rho_t = 0.007576,  held-out perplexity estimate = 939.011614
# 46:  rho_t = 0.007571,  held-out perplexity estimate = 1032.029819
# 47:  rho_t = 0.007566,  held-out perplexity estimate = 1078.117593
# 48:  rho_t = 0.007561,  held-out perplexity estimate = 968.001705
# 49:  rho_t = 0.007556,  held-out perplexity estimate = 813.194273
# 50:  rho_t = 0.007551,  held-out perplexity estimate = 903.798174
# 51:  rho_t = 0.007546,  held-out perplexity estimate = 1073.120708
# 52:  rho_t = 0.007541,  held-out perplexity estimate = 1070.548970
# 53:  rho_t = 0.007536,  held-out perplexity estimate = 885.001915
# 54:  rho_t = 0.007532,  held-out perplexity estimate = 824.816638
# 55:  rho_t = 0.007527,  held-out perplexity estimate = 1103.162550
# 56:  rho_t = 0.007522,  held-out perplexity estimate = 967.891954
# 57:  rho_t = 0.007517,  held-out perplexity estimate = 959.086043
# 58:  rho_t = 0.007512,  held-out perplexity estimate = 1006.098901
# 59:  rho_t = 0.007507,  held-out perplexity estimate = 1048.943489
# 60:  rho_t = 0.007502,  held-out perplexity estimate = 1091.004282
# 61:  rho_t = 0.007498,  held-out perplexity estimate = 740.425225
# 62:  rho_t = 0.007493,  held-out perplexity estimate = 1075.515029
# 63:  rho_t = 0.007488,  held-out perplexity estimate = 929.004199
# 64:  rho_t = 0.007483,  held-out perplexity estimate = 931.413417
# 65:  rho_t = 0.007478,  held-out perplexity estimate = 1003.028259
# 66:  rho_t = 0.007473,  held-out perplexity estimate = 852.322220
# 67:  rho_t = 0.007469,  held-out perplexity estimate = 870.231944
# 68:  rho_t = 0.007464,  held-out perplexity estimate = 922.213384
# 69:  rho_t = 0.007459,  held-out perplexity estimate = 958.930902
# 70:  rho_t = 0.007454,  held-out perplexity estimate = 915.360551
# 71:  rho_t = 0.007450,  held-out perplexity estimate = 932.310107
# 72:  rho_t = 0.007445,  held-out perplexity estimate = 932.368109
# 73:  rho_t = 0.007440,  held-out perplexity estimate = 1114.694256
# 74:  rho_t = 0.007435,  held-out perplexity estimate = 1066.976405
# 75:  rho_t = 0.007431,  held-out perplexity estimate = 960.151399

# %%
olda._lambda.shape
# Out:
# (70, 10235)

# %%
topic_word = olda._lambda  # model.components_ also works
n_top_words = 10
for i, topic_dist in enumerate(topic_word):
    topic_words = n.array(vocab)[n.argsort(topic_dist)][:-(n_top_words+1):-1]
    print(u'Topic {}: {}'.format(i, ' '.join(topic_words)))
# Out:
# Topic 0: verdict chipotle creme liquid bias ox service time par childhood
# Topic 1: bias liquid motherland service ox time brioch babyback menu plate
# Topic 2: infinity bias liquid time hookah dover service estrella vest motherland
# Topic 3: liquid bias slaw time service estrella sud menu fiddle threat
# Topic 4: liquid savory bias time service threat peasant infinity motherland menu
# Topic 5: savory xoxo sill appeasing liquid spot nazi protip slaw sprite
# Topic 6: buttery bias curb somethin hamachi trattorium t-shirt activity misc slaw
# Topic 7: liquid bias time infinity service dover estrella green person fiddle
# Topic 8: rookie liquid bias motherland service bummer green time infinity abalone
# Topic 9: rookie liquid bias time motherland service green bummer penalty vest
# Topic 10: bias service liquid fiddle green time infinity par estrella menu
# Topic 11: savory liquid bias infinity time service nazi slack menu green
# Topic 12: bias liquid estrella time fiddle menu etcetera service green infinity
# Topic 13: bias liquid service estrella infinity dover motherland menu plate skanky
# Topic 14: bias liquid time service motherland fiddle estrella bummer comp cous
# Topic 15: bias liquid slaw service time sud fiddle poke threat rookie
# Topic 16: bias showcase liquid infinity dover time patience uhhh service cal
# Topic 17: savory bias liquid nazi menu service spot showcase time slack
# Topic 18: aspect samosas bias removal tofu lassi lobsicle liquid artichoke riot
# Topic 19: bias liquid service estrella time menu ox par motherland infinity
# Topic 20: bias liquid service time estrella menu green hookah ox fiddle
# Topic 21: chipotle verdict liquid bias creme service time ox estrella green
# Topic 22: bias liquid estrella time service green bummer motherland bottle menu
# Topic 23: liquid bias infinity pumpkin tator cal time guru marinate room
# Topic 24: bias liquid savory service menu time fiddle par tsukeman estrella
# Topic 25: bias liquid service motherland estrella ox time brioch babyback fiddle
# Topic 26: bias liquid service ox time green sud fiddle estrella motherland
# Topic 27: bias liquid menu time estrella service motherland infinity ox threat
# Topic 28: liquid bias motherland threat pantheon estrella time fiddle peasant slaw
# Topic 29: bias liquid service infinity time fiddle chipotle estrella hookah etcetera
# Topic 30: liquid bias wing infinity time green estrella service fiddle par
# Topic 31: liquid bias brioch motherland ox babyback time estrella service infinity
# Topic 32: bias liquid time infinity service dover motherland menu hookah bookmark
# Topic 33: liquid bias threat service chipotle slaw fiddle hotties menu ambrosia
# Topic 34: bias liquid sud time menu penalty motherland infinity peasant slack
# Topic 35: bias liquid slaw estrella threat menu hotties time poke ox
# Topic 36: bias liquid service time savory person fiddle ox vest motherland
# Topic 37: liquid bias savory infinity service time slack menu chipotle person
# Topic 38: liquid bias savory motherland time ox green service estrella babyback
# Topic 39: bias liquid infinity service time vest hookah ox dover menu
# Topic 40: liquid bias service babyback motherland menu time brioch bacon vest
# Topic 41: bias liquid service infinity estrella time fiddle hookah person vest
# Topic 42: liquid savory bias infinity time service slack ox menu estrella
# Topic 43: bias liquid chipotle verdict service ox estrella vest time creme
# Topic 44: rookie liquid motherland rubber bummer clutter time green bias madeleine
# Topic 45: liquid bias time verdict chipotle brioch motherland service slaw savory
# Topic 46: sud bang title favor deli emptiness break nazi liquid abyss
# Topic 47: liquid bias time service infinity savory estrella hookah green brew
# Topic 48: rookie bias liquid service bummer motherland time infinity penalty hookah
# Topic 49: bias liquid service time showcase green estrella peasant bummer infinity
# Topic 50: bias liquid estrella chipotle time ox service verdict motherland etcetera
# Topic 51: liquid bias brioch time babyback estrella motherland ox menu green
# Topic 52: bias liquid infinity buttery hookah service ox dover plate time
# Topic 53: liquid bias savory time menu peasant infinity service motherland bacon
# Topic 54: pantheon liquid bias fry service time infinity bummer motherland chipotle
# Topic 55: bias liquid estrella infinity service time ox vest menu dover
# Topic 56: pantheon fry condo chili veteran bias fettuccini motherland liquid ode
# Topic 57: chipotle creme liquid bias verdict ox estrella service wine green
# Topic 58: liquid bias babyback brioch motherland time ox hookah abalone skanky
# Topic 59: bias chipotle liquid verdict service green ox creme estrella rice
# Topic 60: savory liquid bias infinity service toilet nazi time bookmark peasant
# Topic 61: chipotle verdict liquid bias creme estrella ox time service doorman
# Topic 62: bias liquid keyboard polish green skanky rice ox time estrella
# Topic 63: savory bias liquid infinity service time wine menu ox vest
# Topic 64: babyback circle brioch applebee chap bouche liquid level bias workplace
# Topic 65: liquid bias service threat menu estrella motherland sud green time
# Topic 66: bias liquid time service motherland infinity estrella sud babyback bookmark
# Topic 67: bias savory liquid service time infinity menu motherland bookmark par
# Topic 68: bias liquid estrella motherland time brioch ox babyback hookah bummer
# Topic 69: sisig liquid bias waitperson rookie time green estrella penalty service

# %%
max(olda._lambda[0]
# Out:
# 7.6462190424550149

# %%
for k in range(0, len(testlambda)):
    lambdak = list(testlambda[k, :])
    lambdak = lambdak / sum(lambdak)        
    temp = zip(lambdak, range(0, len(lambdak)))
    temp = sorted(temp, key = lambda x: x[0], reverse=True)
    print 'topic %d:' % (k)
    # feel free to change the "53" here to whatever fits your screen nicely.
    for i in range(0, 53):
        print '%20s  \t---\t  %.4f' % (vocab[temp[i][1]], temp[i][0])
    print
