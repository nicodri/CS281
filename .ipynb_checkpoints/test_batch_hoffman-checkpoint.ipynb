# %%
import sys, re, time, string
import numpy as n
from scipy.special import gammaln, psi

n.random.seed(100000001)
meanchangethresh = 0.000001

def dirichlet_expectation(alpha):
    """
    For a vector theta ~ Dir(alpha), computes E[log(theta)] given alpha.
    """
    if (len(alpha.shape) == 1):
        return(psi(alpha) - psi(n.sum(alpha)))
    return(psi(alpha) - psi(n.sum(alpha, 1))[:, n.newaxis])

def parse_doc_list(docs, vocab):
    """
    Parse a document into a list of word ids and a list of counts,
    or parse a set of documents into two lists of lists of word ids
    and counts.

    Arguments: 
    docs:  List of D documents. Each document must be represented as
           a single string. (Word order is unimportant.) Any
           words not in the vocabulary will be ignored.
    vocab: Dictionary mapping from words to integer ids.

    Returns a pair of lists of lists. 

    The first, wordids, says what vocabulary tokens are present in
    each document. wordids[i][j] gives the jth unique token present in
    document i. (Don't count on these tokens being in any particular
    order.)

    The second, wordcts, says how many times each vocabulary token is
    present. wordcts[i][j] is the number of times that the token given
    by wordids[i][j] appears in document i.
    """
    if (type(docs).__name__ == 'str'):
        temp = list()
        temp.append(docs)
        docs = temp

    D = len(docs)
    
    wordids = list()
    wordcts = list()
    for d in range(0, D):
        #docs[d] = str(docs[d].encode('raw_unicode_escape')).lower()
        #docs[d] = re.sub(r'-', ' ', docs[d])
        #docs[d] = re.sub(r'[^a-z ]', '', docs[d])
        #docs[d] = re.sub(r' +', ' ', docs[d])
        words = string.split(docs[d])
        ddict = dict()
        for word in words:
            if (word in vocab):
                wordtoken = vocab[word]
                if (not wordtoken in ddict):
                    ddict[wordtoken] = 0
                ddict[wordtoken] += 1
        wordids.append(ddict.keys())
        wordcts.append(ddict.values())

    return((wordids, wordcts))

class OnlineLDA:
    """
    Implements online VB for LDA as described in (Hoffman et al. 2010).
    """

    def __init__(self, vocab, K, D, alpha, eta, tau0, kappa):
        """
        Arguments:
        K: Number of topics
        vocab: A set of words to recognize. When analyzing documents, any word
           not in this set will be ignored.
        D: Total number of documents in the population. For a fixed corpus,
           this is the size of the corpus. In the truly online setting, this
           can be an estimate of the maximum number of documents that
           could ever be seen.
        alpha: Hyperparameter for prior on weight vectors theta
        eta: Hyperparameter for prior on topics beta
        tau0: A (positive) learning parameter that downweights early iterations
        kappa: Learning rate: exponential decay rate---should be between
             (0.5, 1.0] to guarantee asymptotic convergence.

        Note that if you pass the same set of D documents in every time and
        set kappa=0 this class can also be used to do batch VB.
        """
        self._vocab = dict()
        for word in vocab:
            word = word.lower()
            word = re.sub(r'[^a-z]', '', word)
            self._vocab[word] = len(self._vocab)

        self._K = K
        self._W = len(self._vocab)
        self._D = D
        self._alpha = alpha
        self._eta = eta
        self._tau0 = tau0 + 1
        self._kappa = kappa
        self._updatect = 0

        # Initialize the variational distribution q(beta|lambda)
        self._lambda = 1*n.random.gamma(100., 1./100., (self._K, self._W))
        self._Elogbeta = dirichlet_expectation(self._lambda)
        self._expElogbeta = n.exp(self._Elogbeta)

    def do_e_step(self, docs):
        """
        Given a mini-batch of documents, estimates the parameters
        gamma controlling the variational distribution over the topic
        weights for each document in the mini-batch.

        Arguments:
        docs:  List of D documents. Each document must be represented
               as a string. (Word order is unimportant.) Any
               words not in the vocabulary will be ignored.

        Returns a tuple containing the estimated values of gamma,
        as well as sufficient statistics needed to update lambda.
        """
        # This is to handle the case where someone just hands us a single
        # document, not in a list.
        if (type(docs).__name__ == 'string'):
            temp = list()
            temp.append(docs)
            docs = temp

        (wordids, wordcts) = parse_doc_list(docs, self._vocab)
        batchD = len(docs)

        # Initialize the variational distribution q(theta|gamma) for
        # the mini-batch
        gamma = 1*n.random.gamma(100., 1./100., (batchD, self._K))
        Elogtheta = dirichlet_expectation(gamma)
        expElogtheta = n.exp(Elogtheta)

        sstats = n.zeros(self._lambda.shape)
        # Now, for each document d update that document's gamma and phi
        it = 0
        meanchange = 0
        for d in range(0, batchD):
            # These are mostly just shorthand (but might help cache locality)
            ids = wordids[d]
            cts = wordcts[d]
            gammad = gamma[d, :]
            Elogthetad = Elogtheta[d, :]
            expElogthetad = expElogtheta[d, :]
            expElogbetad = self._expElogbeta[:, ids]
            # The optimal phi_{dwk} is proportional to 
            # expElogthetad_k * expElogbetad_w. phinorm is the normalizer.
            phinorm = n.dot(expElogthetad, expElogbetad) + 1e-100
            # Iterate between gamma and phi until convergence
            for it in range(0, 100):
                lastgamma = gammad
                # We represent phi implicitly to save memory and time.
                # Substituting the value of the optimal phi back into
                # the update for gamma gives this update. Cf. Lee&Seung 2001.
                gammad = self._alpha + expElogthetad * \
                    n.dot(cts / phinorm, expElogbetad.T)
                Elogthetad = dirichlet_expectation(gammad)
                expElogthetad = n.exp(Elogthetad)
                phinorm = n.dot(expElogthetad, expElogbetad) + 1e-100
                # If gamma hasn't changed much, we're done.
                meanchange = n.mean(abs(gammad - lastgamma))
                if (meanchange < meanchangethresh):
                    break
            gamma[d, :] = gammad
            # Contribution of document d to the expected sufficient
            # statistics for the M step.
            sstats[:, ids] += n.outer(expElogthetad.T, cts/phinorm)

        # This step finishes computing the sufficient statistics for the
        # M step, so that
        # sstats[k, w] = \sum_d n_{dw} * phi_{dwk} 
        # = \sum_d n_{dw} * exp{Elogtheta_{dk} + Elogbeta_{kw}} / phinorm_{dw}.
        sstats = sstats * self._expElogbeta

        return((gamma, sstats))

    def update_lambda(self, docs):
        """
        First does an E step on the mini-batch given in wordids and
        wordcts, then uses the result of that E step to update the
        variational parameter matrix lambda.

        Arguments:
        docs:  List of D documents. Each document must be represented
               as a string. (Word order is unimportant.) Any
               words not in the vocabulary will be ignored.

        Returns gamma, the parameters to the variational distribution
        over the topic weights theta for the documents analyzed in this
        update.

        Also returns an estimate of the variational bound for the
        entire corpus for the OLD setting of lambda based on the
        documents passed in. This can be used as a (possibly very
        noisy) estimate of held-out likelihood.
        """

        # rhot will be between 0 and 1, and says how much to weight
        # the information we got from this mini-batch.
        rhot = pow(self._tau0 + self._updatect, -self._kappa)
        self._rhot = rhot
        # Do an E step to update gamma, phi | lambda for this
        # mini-batch. This also returns the information about phi that
        # we need to update lambda.
        (gamma, sstats) = self.do_e_step(docs)
        # Estimate held-out likelihood for current values of lambda.
        #bound = self.approx_bound(docs, gamma)
        # Update lambda based on documents.
        self._lambda = self._lambda * (1-rhot) + \
            rhot * (self._eta + self._D * sstats / len(docs))
        self._Elogbeta = dirichlet_expectation(self._lambda)
        self._expElogbeta = n.exp(self._Elogbeta)
        self._updatect += 1

        return gamma

    def approx_bound(self, docs, gamma):
        """
        Estimates the variational bound over *all documents* using only
        the documents passed in as "docs." gamma is the set of parameters
        to the variational distribution q(theta) corresponding to the
        set of documents passed in.

        The output of this function is going to be noisy, but can be
        useful for assessing convergence.
        """

        # This is to handle the case where someone just hands us a single
        # document, not in a list.
        if (type(docs).__name__ == 'string'):
            temp = list()
            temp.append(docs)
            docs = temp

        (wordids, wordcts) = parse_doc_list(docs, self._vocab)
        batchD = len(docs)

        score = 0
        Elogtheta = dirichlet_expectation(gamma)
        expElogtheta = n.exp(Elogtheta)

        # E[log p(docs | theta, beta)]
        for d in range(0, batchD):
            gammad = gamma[d, :]
            ids = wordids[d]
            cts = n.array(wordcts[d])
            phinorm = n.zeros(len(ids))
            for i in range(0, len(ids)):
                temp = Elogtheta[d, :] + self._Elogbeta[:, ids[i]]
                tmax = max(temp)
                phinorm[i] = n.log(sum(n.exp(temp - tmax))) + tmax
            score += n.sum(cts * phinorm)
#             oldphinorm = phinorm
#             phinorm = n.dot(expElogtheta[d, :], self._expElogbeta[:, ids])
#             print oldphinorm
#             print n.log(phinorm)
#             score += n.sum(cts * n.log(phinorm))

        # E[log p(theta | alpha) - log q(theta | gamma)]
        score += n.sum((self._alpha - gamma)*Elogtheta)
        score += n.sum(gammaln(gamma) - gammaln(self._alpha))
        score += sum(gammaln(self._alpha*self._K) - gammaln(n.sum(gamma, 1)))

        # Compensate for the subsampling of the population of documents
        score = score * self._D / len(docs)

        # E[log p(beta | eta) - log q (beta | lambda)]
        score = score + n.sum((self._eta-self._lambda)*self._Elogbeta)
        score = score + n.sum(gammaln(self._lambda) - gammaln(self._eta))
        score = score + n.sum(gammaln(self._eta*self._W) - 
                              gammaln(n.sum(self._lambda, 1)))

        return(score)

# %%
# The number of documents to analyze each iteration
batchsize = 50
# The total number of documents in Wikipedia
D = 3800
# The number of topics
K = 40

# %%
vocab =n.load('temp/Lasvegas_data/lv_vocab10.npy')

# %%
vocab = list(vocab)

# %%
toremove = ['food','place','service','time','restaurant','menu','order','price','dish','table','thing','person','experience','server','staff','way','bit','portion','lot','hour','star','plate','course','option','customer','liking']

# %%
for w in toremove:
    vocab.remove(w)

# %%
W = len(vocab)

# %%
W
# Out:
# 10338

# %%
vocab  = dict(zip(vocab,range(len(vocab))))

# %%
olda = OnlineLDA(vocab, K, D, 1./K, 1./K, 1024., 0.7)

# %%
documentstoanalyze = int(D/batchsize)
documentstoanalyze
# Out:
# 76

# %%
import json
with open('../Zipped_data_LV/lasvegas_word_adjective.json', 'r') as fp:
    lv_wadj = json.load(fp)

# %%
docsetbig = [] 
articlenamesbig = []

for k in lv_wadj.keys()[:3800]:
    docsetbig.append(" ".join(lv_wadj[k][0][0]))
    articlenamesbig.append(k)

# %%
docsetbig = n.split(n.array(docsetbig),76)

# %%
for iteration in range(0, documentstoanalyze):
    # Download some articles
    docset = docsetbig[iteration]
    # Give them to online LDA
    gamma = olda.update_lambda(docset)        
    # Compute an estimate of held-out perplexity
    #(wordids, wordcts) = parse_doc_list(docset, olda._vocab)
    print '%d:  rho_t = %f,  held-out perplexity estimate = %f' % (iteration, olda._rhot, n.exp(-perwordbound))
# Out:
# 0:  rho_t = 0.007807,  held-out perplexity estimate = 1007.972812
# 1:  rho_t = 0.007802,  held-out perplexity estimate = 1007.972812
# 2:  rho_t = 0.007797,  held-out perplexity estimate = 1007.972812
# 3:  rho_t = 0.007791,  held-out perplexity estimate = 1007.972812
# 4:  rho_t = 0.007786,  held-out perplexity estimate = 1007.972812
# 5:  rho_t = 0.007781,  held-out perplexity estimate = 1007.972812
# 6:  rho_t = 0.007775,  held-out perplexity estimate = 1007.972812
# 7:  rho_t = 0.007770,  held-out perplexity estimate = 1007.972812
# 8:  rho_t = 0.007765,  held-out perplexity estimate = 1007.972812
# 9:  rho_t = 0.007760,  held-out perplexity estimate = 1007.972812
# 10:  rho_t = 0.007754,  held-out perplexity estimate = 1007.972812
# 11:  rho_t = 0.007749,  held-out perplexity estimate = 1007.972812
# 12:  rho_t = 0.007744,  held-out perplexity estimate = 1007.972812
# 13:  rho_t = 0.007739,  held-out perplexity estimate = 1007.972812
# 14:  rho_t = 0.007733,  held-out perplexity estimate = 1007.972812
# 15:  rho_t = 0.007728,  held-out perplexity estimate = 1007.972812
# 16:  rho_t = 0.007723,  held-out perplexity estimate = 1007.972812
# 17:  rho_t = 0.007718,  held-out perplexity estimate = 1007.972812
# 18:  rho_t = 0.007713,  held-out perplexity estimate = 1007.972812
# 19:  rho_t = 0.007707,  held-out perplexity estimate = 1007.972812
# 20:  rho_t = 0.007702,  held-out perplexity estimate = 1007.972812
# 21:  rho_t = 0.007697,  held-out perplexity estimate = 1007.972812
# 22:  rho_t = 0.007692,  held-out perplexity estimate = 1007.972812
# 23:  rho_t = 0.007687,  held-out perplexity estimate = 1007.972812
# 24:  rho_t = 0.007682,  held-out perplexity estimate = 1007.972812
# 25:  rho_t = 0.007677,  held-out perplexity estimate = 1007.972812
# 26:  rho_t = 0.007671,  held-out perplexity estimate = 1007.972812
# 27:  rho_t = 0.007666,  held-out perplexity estimate = 1007.972812
# 28:  rho_t = 0.007661,  held-out perplexity estimate = 1007.972812
# 29:  rho_t = 0.007656,  held-out perplexity estimate = 1007.972812
# 30:  rho_t = 0.007651,  held-out perplexity estimate = 1007.972812
# 31:  rho_t = 0.007646,  held-out perplexity estimate = 1007.972812
# 32:  rho_t = 0.007641,  held-out perplexity estimate = 1007.972812
# 33:  rho_t = 0.007636,  held-out perplexity estimate = 1007.972812
# 34:  rho_t = 0.007631,  held-out perplexity estimate = 1007.972812
# 35:  rho_t = 0.007626,  held-out perplexity estimate = 1007.972812
# 36:  rho_t = 0.007621,  held-out perplexity estimate = 1007.972812
# 37:  rho_t = 0.007616,  held-out perplexity estimate = 1007.972812
# 38:  rho_t = 0.007611,  held-out perplexity estimate = 1007.972812
# 39:  rho_t = 0.007606,  held-out perplexity estimate = 1007.972812
# 40:  rho_t = 0.007601,  held-out perplexity estimate = 1007.972812
# 41:  rho_t = 0.007596,  held-out perplexity estimate = 1007.972812
# 42:  rho_t = 0.007591,  held-out perplexity estimate = 1007.972812
# 43:  rho_t = 0.007586,  held-out perplexity estimate = 1007.972812
# 44:  rho_t = 0.007581,  held-out perplexity estimate = 1007.972812
# 45:  rho_t = 0.007576,  held-out perplexity estimate = 1007.972812
# 46:  rho_t = 0.007571,  held-out perplexity estimate = 1007.972812
# 47:  rho_t = 0.007566,  held-out perplexity estimate = 1007.972812
# 48:  rho_t = 0.007561,  held-out perplexity estimate = 1007.972812
# 49:  rho_t = 0.007556,  held-out perplexity estimate = 1007.972812
# 50:  rho_t = 0.007551,  held-out perplexity estimate = 1007.972812
# 51:  rho_t = 0.007546,  held-out perplexity estimate = 1007.972812
# 52:  rho_t = 0.007541,  held-out perplexity estimate = 1007.972812
# 53:  rho_t = 0.007536,  held-out perplexity estimate = 1007.972812
# 54:  rho_t = 0.007532,  held-out perplexity estimate = 1007.972812
# 55:  rho_t = 0.007527,  held-out perplexity estimate = 1007.972812
# 56:  rho_t = 0.007522,  held-out perplexity estimate = 1007.972812
# 57:  rho_t = 0.007517,  held-out perplexity estimate = 1007.972812
# 58:  rho_t = 0.007512,  held-out perplexity estimate = 1007.972812
# 59:  rho_t = 0.007507,  held-out perplexity estimate = 1007.972812
# 60:  rho_t = 0.007502,  held-out perplexity estimate = 1007.972812
# 61:  rho_t = 0.007498,  held-out perplexity estimate = 1007.972812
# 62:  rho_t = 0.007493,  held-out perplexity estimate = 1007.972812
# 63:  rho_t = 0.007488,  held-out perplexity estimate = 1007.972812
# 64:  rho_t = 0.007483,  held-out perplexity estimate = 1007.972812
# 65:  rho_t = 0.007478,  held-out perplexity estimate = 1007.972812
# 66:  rho_t = 0.007473,  held-out perplexity estimate = 1007.972812
# 67:  rho_t = 0.007469,  held-out perplexity estimate = 1007.972812
# 68:  rho_t = 0.007464,  held-out perplexity estimate = 1007.972812
# 69:  rho_t = 0.007459,  held-out perplexity estimate = 1007.972812
# 70:  rho_t = 0.007454,  held-out perplexity estimate = 1007.972812
# 71:  rho_t = 0.007450,  held-out perplexity estimate = 1007.972812
# 72:  rho_t = 0.007445,  held-out perplexity estimate = 1007.972812
# 73:  rho_t = 0.007440,  held-out perplexity estimate = 1007.972812
# 74:  rho_t = 0.007435,  held-out perplexity estimate = 1007.972812
# 75:  rho_t = 0.007431,  held-out perplexity estimate = 1007.972812

# %%
olda._lambda.shape
# Out:
# (40, 10235)

# %%
vocab['document']
# Out:
# 3653

# %%
topic_word = olda._lambda  # model.components_ also works
n_top_words = 10
for i, topic_dist in enumerate(topic_word):
    topic_words = n.array(vocab.keys())[n.argsort(topic_dist)][:-(n_top_words+1):-1]
    print(u'Topic {}: {}'.format(i, ' '.join(topic_words)))
# Out:
# Topic 0: campechana buttery roll rice kebab mention flow musubis bummer abalone
# Topic 1: fundido shumai cristo sidekick test solace cetera prick motherland sud
# Topic 2: motherland horde brioch outbreak par sheep crunchy drunkenness bummer flick
# Topic 3: sud motherland fondant carry-out band offender par prick mention wine
# Topic 4: motherland outbreak brioch horde bummer crunchy discontent retreat par mention
# Topic 5: leeway yelpster clove visit lassi artichoke gyozas generation coating mention
# Topic 6: carry-out motherland outbreak horde taylor sheep spectacle spot brioch prick
# Topic 7: outbreak carry-out folk frittus mention motherland discontent prick eavesdropping fork
# Topic 8: motherland outbreak bummer horde par sheep bacon brioch discontent crunchy
# Topic 9: motherland horde prick brioch wine bacon fiasco sheep abalone outbreak
# Topic 10: horde brioch motherland bummer chap outbreak retreat crunchy fiasco jowl
# Topic 11: mention pinball outbreak motherland prick fork coating bummer sud fiasco
# Topic 12: mention coating starters motherland par outbreak folk sheep bummer crunchy
# Topic 13: outbreak carry-out brioch retreat discontent fiasco crunchy horde sheep motherland
# Topic 14: wing motherland sud par fry starters mention duration coating bummer
# Topic 15: horde pretty brioch drunkenness chap offender carafes sud motherland function
# Topic 16: trotter sisig framboise gizzard filipino acknowledgment garage lorraine better nod
# Topic 17: carry-out americano sill hospital ignore economy taylor spot spectacle protip
# Topic 18: outbreak motherland discontent wine brioch horde mention bummer fiasco crunchy
# Topic 19: musubis horde kebab bummer abalone motherland par downturn brioch sud
# Topic 20: outbreak discontent snarky folk close-by purge music nazi southwest mention
# Topic 21: carry-out outbreak motherland fiasco taylor mention coating par sheep fork
# Topic 22: carry-out spectacle outbreak taylor spot wing par sud fiasco fry
# Topic 23: fondant bummer motherland horde mention outbreak coating starters brioch discontent
# Topic 24: seed remaining chili fry ooo soooooo motherland corridor topping field
# Topic 25: prepared bar-b-que outbreak pre-dinner gown jazz motherland seal brioch discontent
# Topic 26: carry-out outbreak spot spectacle fiasco par bummer taylor dryer fungi
# Topic 27: motherland retreat brioch horde outbreak bummer par mention musubis bacon
# Topic 28: carry-out starters sud motherland outbreak fork horde fondant slush spectacle
# Topic 29: outbreak wine motherland sheep brioch retreat starters horde crunchy bummer
# Topic 30: sud horde carry-out motherland band brioch wine outbreak uno starters
# Topic 31: fondant rubber discrepancy motherland bummer chilling wing starters olio pork
# Topic 32: kick arepas bummer motherland abalone brioch bacon horde outbreak fiasco
# Topic 33: brioch horde bummer motherland abalone retreat uno crunchy mention sud
# Topic 34: mention bummer starters dryer motherland rice par folk eavesdropping covering
# Topic 35: kebab par motherland eavesdropping fondant mention musubis bummer downturn wine
# Topic 36: nutrient eavesdropping bummer mention covering fry motherland starters outbreak retreat
# Topic 37: folk meats purge tika southwest dictate dryer outbreak thi rice
# Topic 38: fondant motherland outbreak rubber starters retreat fork topping pinball discontent
# Topic 39: prick fork mention musubis kebab napkin motherland click par sud

# %%
max(olda._lambda[0]
# Out:
# 7.6462190424550149

# %%
testlambda = olda._lambda
for k in range(0, len(testlambda)):
    lambdak = list(testlambda[k, :])
    lambdak = lambdak / sum(lambdak)        
    temp = zip(lambdak, range(0, len(lambdak)))
    temp = sorted(temp, key = lambda x: x[0], reverse=True)
    print 'topic %d:' % (k)
    # feel free to change the "53" here to whatever fits your screen nicely.
    for i in range(0, 53):
        print '%20s  \t---\t  %.4f' % (vocab[temp[i][1]], temp[i][0])
    print
# Out:
# topic 0:
#              verdict  	---	  0.0013
#             chipotle  	---	  0.0013
#                creme  	---	  0.0010
#               liquid  	---	  0.0008
#                 bias  	---	  0.0006
#                   ox  	---	  0.0004
#              service  	---	  0.0004
#                 time  	---	  0.0004
#                  par  	---	  0.0003
#            childhood  	---	  0.0003
#               kickin  	---	  0.0003
#           spicy-ness  	---	  0.0003
#                 comp  	---	  0.0003
#             estrella  	---	  0.0003
#             peruvian  	---	  0.0003
#              gelatus  	---	  0.0003
#               bummer  	---	  0.0003
#                green  	---	  0.0003
#                stare  	---	  0.0002
#              peasant  	---	  0.0002
#               person  	---	  0.0002
#                 rice  	---	  0.0002
#                diego  	---	  0.0002
#             brandade  	---	  0.0002
#                 vest  	---	  0.0002
#               hookah  	---	  0.0002
#            seasoning  	---	  0.0002
#                 yoly  	---	  0.0002
#                chili  	---	  0.0002
#                 roll  	---	  0.0002
#          underground  	---	  0.0002
#                 task  	---	  0.0002
#               skanky  	---	  0.0002
#             keyboard  	---	  0.0002
#            headliner  	---	  0.0002
#               toilet  	---	  0.0002
#                 cous  	---	  0.0002
#               bottle  	---	  0.0002
#             etcetera  	---	  0.0002
#              stumble  	---	  0.0002
#                 hole  	---	  0.0002
#              briefly  	---	  0.0002
#                plate  	---	  0.0002
#            wallpaper  	---	  0.0002
#                 reso  	---	  0.0002
#             bookmark  	---	  0.0002
#               brioch  	---	  0.0002
#              viewing  	---	  0.0002
#                 fuss  	---	  0.0002
#       sustainability  	---	  0.0002
#                sound  	---	  0.0002
#                  jun  	---	  0.0002
#                 menu  	---	  0.0002
#
# topic 1:
#                 bias  	---	  0.0004
#               liquid  	---	  0.0004
#           motherland  	---	  0.0003
#              service  	---	  0.0003
#                   ox  	---	  0.0003
#                 time  	---	  0.0003
#               brioch  	---	  0.0002
#             babyback  	---	  0.0002
#                 menu  	---	  0.0002
#                plate  	---	  0.0002
#               hookah  	---	  0.0002
#               person  	---	  0.0002
#             estrella  	---	  0.0002
#             accuracy  	---	  0.0002
#              penalty  	---	  0.0002
#             bookmark  	---	  0.0002
#                 chap  	---	  0.0002
#                 wine  	---	  0.0002
#             infinity  	---	  0.0002
#                bacon  	---	  0.0002
#              peasant  	---	  0.0002
#                stare  	---	  0.0002
#                 brew  	---	  0.0002
#                  par  	---	  0.0002
#          vinaigrette  	---	  0.0002
#                tator  	---	  0.0002
#           discomfort  	---	  0.0002
#                 task  	---	  0.0002
#             applebee  	---	  0.0002
#          bachlorette  	---	  0.0002
#                green  	---	  0.0002
#             keyboard  	---	  0.0002
#               bummer  	---	  0.0002
#             somethin  	---	  0.0002
#                 canh  	---	  0.0002
#               noodle  	---	  0.0002
#               skanky  	---	  0.0002
#                 bang  	---	  0.0002
#               threat  	---	  0.0001
#              stumble  	---	  0.0001
#          underground  	---	  0.0001
#                 cous  	---	  0.0001
#             chipotle  	---	  0.0001
#                 vest  	---	  0.0001
#             euphoria  	---	  0.0001
#               watier  	---	  0.0001
#                  snd  	---	  0.0001
#             ambrosia  	---	  0.0001
#               cherry  	---	  0.0001
#                 tuna  	---	  0.0001
#               search  	---	  0.0001
#              abalone  	---	  0.0001
#                  ham  	---	  0.0001
#
# topic 2:
#             infinity  	---	  0.0015
#                 bias  	---	  0.0015
#               liquid  	---	  0.0013
#                 time  	---	  0.0007
#               hookah  	---	  0.0007
#                dover  	---	  0.0006
#              service  	---	  0.0006
#             estrella  	---	  0.0006
#                 vest  	---	  0.0005
#           motherland  	---	  0.0005
#               skanky  	---	  0.0005
#               brioch  	---	  0.0005
#                   ox  	---	  0.0005
#                award  	---	  0.0005
#                 menu  	---	  0.0005
#             babyback  	---	  0.0005
#                suede  	---	  0.0004
#              penalty  	---	  0.0004
#                plate  	---	  0.0004
#               bummer  	---	  0.0004
#               cherry  	---	  0.0004
#              peasant  	---	  0.0004
#              stumble  	---	  0.0004
#              abalone  	---	  0.0004
#                 nosh  	---	  0.0004
#                green  	---	  0.0004
#                 brew  	---	  0.0004
#                 wine  	---	  0.0004
#             bookmark  	---	  0.0004
#          underground  	---	  0.0004
#               fiddle  	---	  0.0003
#               person  	---	  0.0003
#            confettus  	---	  0.0003
#                tator  	---	  0.0003
#             keyboard  	---	  0.0003
#              tangine  	---	  0.0003
#                stare  	---	  0.0003
#            yorkshire  	---	  0.0003
#                  par  	---	  0.0003
#              riviera  	---	  0.0003
#                music  	---	  0.0003
#                drape  	---	  0.0003
#               bottle  	---	  0.0003
#                 task  	---	  0.0003
#                  lap  	---	  0.0003
#                diego  	---	  0.0003
#             accuracy  	---	  0.0003
#          bachlorette  	---	  0.0003
#            quotation  	---	  0.0003
#                 tuna  	---	  0.0003
#                slush  	---	  0.0002
#                bacon  	---	  0.0002
#                  sud  	---	  0.0002
#
# topic 3:
#               liquid  	---	  0.0048
#                 bias  	---	  0.0046
#                 slaw  	---	  0.0029
#                 time  	---	  0.0028
#              service  	---	  0.0024
#             estrella  	---	  0.0023
#                  sud  	---	  0.0022
#                 menu  	---	  0.0022
#               fiddle  	---	  0.0022
#               threat  	---	  0.0019
#           motherland  	---	  0.0016
#              penalty  	---	  0.0014
#                green  	---	  0.0014
#                 vest  	---	  0.0014
#                slack  	---	  0.0013
#              hotties  	---	  0.0013
#             etcetera  	---	  0.0013
#                 poke  	---	  0.0012
#                   ox  	---	  0.0012
#              peasant  	---	  0.0011
#                 bang  	---	  0.0011
#               savory  	---	  0.0011
#               watier  	---	  0.0011
#             tsukeman  	---	  0.0011
#              abalone  	---	  0.0010
#                bacon  	---	  0.0010
#             bookmark  	---	  0.0010
#             keyboard  	---	  0.0009
#               bummer  	---	  0.0009
#                  par  	---	  0.0009
#              stumble  	---	  0.0009
#             ambrosia  	---	  0.0008
#              riviera  	---	  0.0008
#                plate  	---	  0.0008
#                tator  	---	  0.0007
#               person  	---	  0.0007
#                 brew  	---	  0.0007
#                  cal  	---	  0.0007
#               quizno  	---	  0.0007
#                 baby  	---	  0.0007
#           chandelier  	---	  0.0007
#                 task  	---	  0.0007
#               marrow  	---	  0.0007
#                diego  	---	  0.0007
#              verdict  	---	  0.0007
#               hookah  	---	  0.0007
#                stare  	---	  0.0007
#               bottle  	---	  0.0006
#                drape  	---	  0.0006
#                slush  	---	  0.0006
#            diversion  	---	  0.0006
#                 cent  	---	  0.0006
#               bomber  	---	  0.0006
#
# topic 4:
#               liquid  	---	  0.0023
#               savory  	---	  0.0018
#                 bias  	---	  0.0016
#                 time  	---	  0.0012
#              service  	---	  0.0010
#               threat  	---	  0.0008
#              peasant  	---	  0.0007
#             infinity  	---	  0.0007
#           motherland  	---	  0.0007
#                 menu  	---	  0.0007
#                 slaw  	---	  0.0006
#                  sud  	---	  0.0006
#               fiddle  	---	  0.0006
#             etcetera  	---	  0.0006
#                 vest  	---	  0.0006
#                   ox  	---	  0.0006
#                slack  	---	  0.0006
#             estrella  	---	  0.0006
#               person  	---	  0.0005
#               hookah  	---	  0.0005
#                bacon  	---	  0.0005
#                 brew  	---	  0.0005
#               toilet  	---	  0.0005
#              abalone  	---	  0.0005
#                 nazi  	---	  0.0005
#                 poke  	---	  0.0005
#             bookmark  	---	  0.0004
#                green  	---	  0.0004
#              stumble  	---	  0.0004
#               bomber  	---	  0.0004
#              hotties  	---	  0.0004
#               bottle  	---	  0.0004
#                  par  	---	  0.0004
#                 spot  	---	  0.0004
#                slush  	---	  0.0004
#                stare  	---	  0.0004
#                diego  	---	  0.0004
#                 task  	---	  0.0004
#            diversion  	---	  0.0004
#              riviera  	---	  0.0004
#                drape  	---	  0.0004
#               bummer  	---	  0.0004
#                 bang  	---	  0.0003
#            newspaper  	---	  0.0003
#             keyboard  	---	  0.0003
#               quizno  	---	  0.0003
#               marrow  	---	  0.0003
#               watier  	---	  0.0003
#             ambrosia  	---	  0.0003
#                dover  	---	  0.0003
#                  lap  	---	  0.0003
#                plate  	---	  0.0003
#              penalty  	---	  0.0003
#
# topic 5:
#               savory  	---	  0.0824
#                 xoxo  	---	  0.0329
#                 sill  	---	  0.0223
#            appeasing  	---	  0.0176
#               liquid  	---	  0.0139
#                 spot  	---	  0.0123
#                 nazi  	---	  0.0115
#               protip  	---	  0.0075
#                 slaw  	---	  0.0071
#               sprite  	---	  0.0070
#               toilet  	---	  0.0070
#               thesis  	---	  0.0067
#             infinity  	---	  0.0066
#                 fine  	---	  0.0060
#              belting  	---	  0.0059
#                  sud  	---	  0.0057
#                 kind  	---	  0.0054
#                 shop  	---	  0.0052
#                shiso  	---	  0.0052
#                mocha  	---	  0.0048
#            foodcourt  	---	  0.0041
#                   li  	---	  0.0039
#              service  	---	  0.0036
#                 time  	---	  0.0035
#             handicap  	---	  0.0034
#                slack  	---	  0.0034
#                 bias  	---	  0.0033
#             grouping  	---	  0.0033
#                boozy  	---	  0.0032
#                 roja  	---	  0.0029
#           contention  	---	  0.0029
#                greed  	---	  0.0028
#             guidance  	---	  0.0028
#                drape  	---	  0.0028
#               avenue  	---	  0.0026
#                  mat  	---	  0.0025
#                halwa  	---	  0.0025
#          showmanship  	---	  0.0025
#                slush  	---	  0.0024
#          observation  	---	  0.0024
#           motherland  	---	  0.0023
#                  par  	---	  0.0023
#              sojourn  	---	  0.0023
#                  jim  	---	  0.0023
#                 kiwi  	---	  0.0022
#                 brew  	---	  0.0022
#               person  	---	  0.0022
#                green  	---	  0.0021
#                clash  	---	  0.0021
#                 deco  	---	  0.0021
#             macaroon  	---	  0.0020
#              peasant  	---	  0.0020
#                manga  	---	  0.0019
#
# topic 6:
#              buttery  	---	  0.0814
#                 bias  	---	  0.0359
#                 curb  	---	  0.0265
#             somethin  	---	  0.0203
#              hamachi  	---	  0.0164
#           trattorium  	---	  0.0163
#              t-shirt  	---	  0.0162
#             activity  	---	  0.0135
#                 misc  	---	  0.0135
#                 slaw  	---	  0.0121
#                   li  	---	  0.0116
#               origin  	---	  0.0105
#       sustainability  	---	  0.0093
#               hookah  	---	  0.0092
#               cherry  	---	  0.0090
#                 cent  	---	  0.0089
#                 time  	---	  0.0089
#              replica  	---	  0.0088
#              peasant  	---	  0.0083
#                clock  	---	  0.0082
#               bomber  	---	  0.0067
#              penalty  	---	  0.0067
#                stare  	---	  0.0067
#                plate  	---	  0.0067
#             diarrhea  	---	  0.0065
#           old-school  	---	  0.0063
#              product  	---	  0.0062
#               person  	---	  0.0059
#             shutdown  	---	  0.0059
#              abalone  	---	  0.0059
#                 frys  	---	  0.0057
#               liquid  	---	  0.0057
#             etcetera  	---	  0.0055
#             figurine  	---	  0.0053
#                dover  	---	  0.0050
#                 poki  	---	  0.0047
#                   ox  	---	  0.0047
#               quizno  	---	  0.0045
#                 cous  	---	  0.0043
#                 tini  	---	  0.0042
#            madeleine  	---	  0.0041
#               choice  	---	  0.0040
#               rookie  	---	  0.0039
#                drape  	---	  0.0037
#             mattress  	---	  0.0036
#              service  	---	  0.0035
#              frescas  	---	  0.0035
#             brandade  	---	  0.0034
#              stumble  	---	  0.0034
#            scavenger  	---	  0.0034
#          underground  	---	  0.0033
#           motherland  	---	  0.0031
#                 limo  	---	  0.0031
#
# topic 7:
#               liquid  	---	  0.0013
#                 bias  	---	  0.0012
#                 time  	---	  0.0011
#             infinity  	---	  0.0008
#              service  	---	  0.0008
#                dover  	---	  0.0006
#             estrella  	---	  0.0005
#                green  	---	  0.0005
#               person  	---	  0.0005
#               fiddle  	---	  0.0004
#               skanky  	---	  0.0004
#                 brew  	---	  0.0004
#               hookah  	---	  0.0004
#                tator  	---	  0.0004
#                 vest  	---	  0.0004
#              peasant  	---	  0.0004
#                suede  	---	  0.0004
#             keyboard  	---	  0.0004
#                  cal  	---	  0.0003
#             etcetera  	---	  0.0003
#             bookmark  	---	  0.0003
#               bottle  	---	  0.0003
#                   ox  	---	  0.0003
#              riviera  	---	  0.0003
#             showcase  	---	  0.0003
#                 menu  	---	  0.0003
#                drape  	---	  0.0003
#              tangine  	---	  0.0003
#                slack  	---	  0.0003
#               cherry  	---	  0.0003
#                plate  	---	  0.0003
#               search  	---	  0.0003
#                  snd  	---	  0.0003
#               nachos  	---	  0.0003
#            quotation  	---	  0.0003
#            yorkshire  	---	  0.0003
#                 task  	---	  0.0003
#             patience  	---	  0.0003
#                award  	---	  0.0003
#               bummer  	---	  0.0003
#                music  	---	  0.0003
#           motherland  	---	  0.0003
#             babyback  	---	  0.0003
#              stumble  	---	  0.0003
#                diego  	---	  0.0003
#              brownie  	---	  0.0002
#                  lap  	---	  0.0002
#                slush  	---	  0.0002
#                  sud  	---	  0.0002
#                stare  	---	  0.0002
#                bacon  	---	  0.0002
#          underground  	---	  0.0002
#              penalty  	---	  0.0002
#
# topic 8:
#               rookie  	---	  0.0005
#               liquid  	---	  0.0004
#                 bias  	---	  0.0003
#           motherland  	---	  0.0003
#              service  	---	  0.0003
#               bummer  	---	  0.0002
#                green  	---	  0.0002
#                 time  	---	  0.0002
#             infinity  	---	  0.0002
#              abalone  	---	  0.0002
#              peasant  	---	  0.0002
#                 task  	---	  0.0002
#               skanky  	---	  0.0002
#                 vest  	---	  0.0002
#             keyboard  	---	  0.0002
#                   ox  	---	  0.0002
#              penalty  	---	  0.0002
#              pinball  	---	  0.0002
#               threat  	---	  0.0002
#                 bang  	---	  0.0002
#                  dig  	---	  0.0002
#             babyback  	---	  0.0002
#                 chap  	---	  0.0002
#               bottle  	---	  0.0002
#                  par  	---	  0.0002
#                  snd  	---	  0.0002
#                dover  	---	  0.0002
#               hookah  	---	  0.0001
#                plate  	---	  0.0001
#                 menu  	---	  0.0001
#                 slaw  	---	  0.0001
#                tator  	---	  0.0001
#               person  	---	  0.0001
#               marrow  	---	  0.0001
#          underground  	---	  0.0001
#               choice  	---	  0.0001
#               brioch  	---	  0.0001
#          bachlorette  	---	  0.0001
#                 brew  	---	  0.0001
#             brandade  	---	  0.0001
#                 curb  	---	  0.0001
#                  sud  	---	  0.0001
#             applebee  	---	  0.0001
#             estrella  	---	  0.0001
#              riviera  	---	  0.0001
#            jalapeños  	---	  0.0001
#                 baby  	---	  0.0001
#               rubber  	---	  0.0001
#             whomever  	---	  0.0001
#                slack  	---	  0.0001
#                 shui  	---	  0.0001
#                 wine  	---	  0.0001
#                  jun  	---	  0.0001
#
# topic 9:
#               rookie  	---	  0.0056
#               liquid  	---	  0.0047
#                 bias  	---	  0.0032
#                 time  	---	  0.0025
#           motherland  	---	  0.0025
#              service  	---	  0.0021
#                green  	---	  0.0020
#               bummer  	---	  0.0015
#              penalty  	---	  0.0013
#                 vest  	---	  0.0013
#             estrella  	---	  0.0013
#               fiddle  	---	  0.0013
#                   ox  	---	  0.0013
#             infinity  	---	  0.0012
#               skanky  	---	  0.0012
#                plate  	---	  0.0011
#                 menu  	---	  0.0011
#                 wine  	---	  0.0011
#               hookah  	---	  0.0011
#               person  	---	  0.0010
#                  par  	---	  0.0010
#              peasant  	---	  0.0009
#                bacon  	---	  0.0009
#              pinball  	---	  0.0008
#                stare  	---	  0.0008
#              riviera  	---	  0.0008
#               brioch  	---	  0.0008
#               search  	---	  0.0008
#                 bang  	---	  0.0008
#             bookmark  	---	  0.0008
#                 task  	---	  0.0008
#               threat  	---	  0.0007
#               marrow  	---	  0.0007
#                slack  	---	  0.0007
#               bottle  	---	  0.0007
#               rubber  	---	  0.0007
#                  sud  	---	  0.0007
#                 slaw  	---	  0.0007
#                 brew  	---	  0.0007
#              stumble  	---	  0.0006
#                tator  	---	  0.0006
#          underground  	---	  0.0006
#             ambrosia  	---	  0.0006
#              buttery  	---	  0.0006
#              abalone  	---	  0.0006
#             etcetera  	---	  0.0006
#                 cane  	---	  0.0006
#                slush  	---	  0.0006
#              tangine  	---	  0.0005
#             keyboard  	---	  0.0005
#               cherry  	---	  0.0005
#                dover  	---	  0.0005
#             chipotle  	---	  0.0005
#
# topic 10:
#                 bias  	---	  0.0022
#              service  	---	  0.0016
#               liquid  	---	  0.0015
#               fiddle  	---	  0.0013
#                green  	---	  0.0010
#                 time  	---	  0.0010
#             infinity  	---	  0.0009
#                  par  	---	  0.0008
#             estrella  	---	  0.0008
#                 menu  	---	  0.0008
#                 wing  	---	  0.0007
#                  fry  	---	  0.0007
#                 rice  	---	  0.0006
#               threat  	---	  0.0006
#               bummer  	---	  0.0006
#             etcetera  	---	  0.0006
#              verdict  	---	  0.0005
#               hookah  	---	  0.0005
#                 vest  	---	  0.0005
#             brandade  	---	  0.0005
#                 slaw  	---	  0.0005
#             bookmark  	---	  0.0005
#           motherland  	---	  0.0005
#              peasant  	---	  0.0004
#               toilet  	---	  0.0004
#             keyboard  	---	  0.0004
#                 cous  	---	  0.0004
#                dover  	---	  0.0004
#              riviera  	---	  0.0004
#                slack  	---	  0.0004
#               skanky  	---	  0.0004
#               person  	---	  0.0004
#              tangine  	---	  0.0004
#              abalone  	---	  0.0004
#                 baby  	---	  0.0004
#               search  	---	  0.0004
#                drape  	---	  0.0004
#             tsukeman  	---	  0.0004
#               bottle  	---	  0.0004
#              pinball  	---	  0.0004
#               savory  	---	  0.0004
#                 cane  	---	  0.0004
#                 brew  	---	  0.0003
#              stumble  	---	  0.0003
#                  sud  	---	  0.0003
#                tator  	---	  0.0003
#              hotties  	---	  0.0003
#          underground  	---	  0.0003
#                   ox  	---	  0.0003
#              tagline  	---	  0.0003
#             showcase  	---	  0.0003
#               cherry  	---	  0.0003
#             chipotle  	---	  0.0003
#
# topic 11:
#               savory  	---	  0.0035
#               liquid  	---	  0.0034
#                 bias  	---	  0.0023
#             infinity  	---	  0.0014
#                 time  	---	  0.0013
#              service  	---	  0.0012
#                 nazi  	---	  0.0011
#                slack  	---	  0.0010
#                 menu  	---	  0.0009
#                green  	---	  0.0008
#              peasant  	---	  0.0008
#                 spot  	---	  0.0007
#               toilet  	---	  0.0007
#                   ox  	---	  0.0007
#               quizno  	---	  0.0007
#               rookie  	---	  0.0006
#           motherland  	---	  0.0006
#                 vest  	---	  0.0006
#             estrella  	---	  0.0006
#                 brew  	---	  0.0006
#               hookah  	---	  0.0006
#               brioch  	---	  0.0006
#               person  	---	  0.0005
#         extravaganza  	---	  0.0005
#                tator  	---	  0.0005
#             bookmark  	---	  0.0005
#              penalty  	---	  0.0005
#              stumble  	---	  0.0005
#                 task  	---	  0.0005
#                 wine  	---	  0.0005
#                stare  	---	  0.0005
#             babyback  	---	  0.0005
#             keyboard  	---	  0.0005
#                 cali  	---	  0.0005
#                 slaw  	---	  0.0005
#                  sud  	---	  0.0005
#               skanky  	---	  0.0005
#                plate  	---	  0.0005
#               fiddle  	---	  0.0005
#              riviera  	---	  0.0004
#                drape  	---	  0.0004
#             grouping  	---	  0.0004
#               search  	---	  0.0004
#               bummer  	---	  0.0004
#             brandade  	---	  0.0004
#          underground  	---	  0.0004
#                slush  	---	  0.0004
#            newspaper  	---	  0.0004
#                  par  	---	  0.0004
#               cherry  	---	  0.0004
#              pinball  	---	  0.0004
#                 xoxo  	---	  0.0004
#                music  	---	  0.0004
#
# topic 12:
#                 bias  	---	  0.0026
#               liquid  	---	  0.0013
#             estrella  	---	  0.0011
#                 time  	---	  0.0009
#               fiddle  	---	  0.0009
#                 menu  	---	  0.0008
#             etcetera  	---	  0.0007
#              service  	---	  0.0007
#                green  	---	  0.0006
#             infinity  	---	  0.0006
#                 vest  	---	  0.0006
#               hookah  	---	  0.0005
#               bummer  	---	  0.0005
#              peasant  	---	  0.0005
#               person  	---	  0.0005
#                dover  	---	  0.0005
#           motherland  	---	  0.0004
#              penalty  	---	  0.0004
#                diego  	---	  0.0004
#                  lap  	---	  0.0004
#              stumble  	---	  0.0004
#             keyboard  	---	  0.0004
#                tator  	---	  0.0004
#                  par  	---	  0.0004
#                   ox  	---	  0.0004
#               aspect  	---	  0.0003
#                 task  	---	  0.0003
#                 rice  	---	  0.0003
#             bookmark  	---	  0.0003
#              riviera  	---	  0.0003
#                 brew  	---	  0.0003
#               skanky  	---	  0.0003
#                 bang  	---	  0.0003
#                stare  	---	  0.0003
#                scene  	---	  0.0003
#             brandade  	---	  0.0003
#                 canh  	---	  0.0003
#         extravaganza  	---	  0.0003
#               threat  	---	  0.0003
#              tangine  	---	  0.0003
#                award  	---	  0.0003
#               cherry  	---	  0.0003
#                slack  	---	  0.0003
#                drape  	---	  0.0003
#               bottle  	---	  0.0003
#                 comp  	---	  0.0003
#               watier  	---	  0.0003
#                 slaw  	---	  0.0003
#             tsukeman  	---	  0.0003
#               bomber  	---	  0.0003
#              brownie  	---	  0.0003
#              hotties  	---	  0.0003
#                suede  	---	  0.0003
#
# topic 13:
#                 bias  	---	  0.0011
#               liquid  	---	  0.0009
#              service  	---	  0.0007
#             estrella  	---	  0.0006
#             infinity  	---	  0.0005
#                dover  	---	  0.0005
#           motherland  	---	  0.0005
#                 menu  	---	  0.0004
#                plate  	---	  0.0004
#               skanky  	---	  0.0004
#                 wine  	---	  0.0004
#                 time  	---	  0.0004
#               fiddle  	---	  0.0004
#                 vest  	---	  0.0004
#               person  	---	  0.0003
#                   ox  	---	  0.0003
#               bummer  	---	  0.0003
#                tator  	---	  0.0003
#                green  	---	  0.0003
#                 brew  	---	  0.0003
#              stumble  	---	  0.0003
#               hookah  	---	  0.0003
#                  lap  	---	  0.0003
#                diego  	---	  0.0003
#               cherry  	---	  0.0003
#                 bang  	---	  0.0003
#             showcase  	---	  0.0003
#                  cal  	---	  0.0003
#               brioch  	---	  0.0003
#             keyboard  	---	  0.0003
#              peasant  	---	  0.0003
#             babyback  	---	  0.0003
#                slack  	---	  0.0003
#          underground  	---	  0.0002
#             bookmark  	---	  0.0002
#               bottle  	---	  0.0002
#              riviera  	---	  0.0002
#                bacon  	---	  0.0002
#           date-night  	---	  0.0002
#             chipotle  	---	  0.0002
#          bachlorette  	---	  0.0002
#             etcetera  	---	  0.0002
#                drape  	---	  0.0002
#                 uhhh  	---	  0.0002
#                music  	---	  0.0002
#               nachos  	---	  0.0002
#               threat  	---	  0.0002
#            quotation  	---	  0.0002
#              hotties  	---	  0.0002
#                award  	---	  0.0002
#                 task  	---	  0.0002
#              brownie  	---	  0.0002
#                 curb  	---	  0.0002
#
# topic 14:
#                 bias  	---	  0.0011
#               liquid  	---	  0.0007
#                 time  	---	  0.0005
#              service  	---	  0.0005
#           motherland  	---	  0.0005
#               fiddle  	---	  0.0004
#             estrella  	---	  0.0004
#               bummer  	---	  0.0004
#                 comp  	---	  0.0004
#                 cous  	---	  0.0003
#                   ox  	---	  0.0003
#                plate  	---	  0.0003
#              penalty  	---	  0.0003
#                 menu  	---	  0.0003
#                  par  	---	  0.0003
#               person  	---	  0.0003
#              sharing  	---	  0.0003
#             tsukeman  	---	  0.0003
#                bacon  	---	  0.0003
#                green  	---	  0.0003
#                 rice  	---	  0.0003
#                stare  	---	  0.0003
#             keyboard  	---	  0.0003
#               hookah  	---	  0.0003
#              riviera  	---	  0.0003
#              peasant  	---	  0.0003
#               threat  	---	  0.0003
#              pinball  	---	  0.0003
#                 vest  	---	  0.0003
#                  cal  	---	  0.0002
#               brioch  	---	  0.0002
#                 wine  	---	  0.0002
#             chipotle  	---	  0.0002
#               cherry  	---	  0.0002
#                dover  	---	  0.0002
#             bookmark  	---	  0.0002
#             etcetera  	---	  0.0002
#             showcase  	---	  0.0002
#                 bang  	---	  0.0002
#              stumble  	---	  0.0002
#             peruvian  	---	  0.0002
#             infinity  	---	  0.0002
#                slack  	---	  0.0002
#                 tide  	---	  0.0002
#             babyback  	---	  0.0002
#                 task  	---	  0.0002
#                 brew  	---	  0.0002
#             patience  	---	  0.0002
#                 slaw  	---	  0.0002
#               rookie  	---	  0.0002
#                 baby  	---	  0.0002
#          underground  	---	  0.0002
#              cholula  	---	  0.0002
#
# topic 15:
#                 bias  	---	  0.0002
#               liquid  	---	  0.0002
#                 slaw  	---	  0.0002
#              service  	---	  0.0002
#                 time  	---	  0.0002
#                  sud  	---	  0.0002
#               fiddle  	---	  0.0002
#                 poke  	---	  0.0002
#               threat  	---	  0.0002
#               rookie  	---	  0.0002
#              hotties  	---	  0.0002
#                dread  	---	  0.0002
#              penalty  	---	  0.0002
#             estrella  	---	  0.0001
#               hookah  	---	  0.0001
#                decor  	---	  0.0001
#           manicottus  	---	  0.0001
#                slack  	---	  0.0001
#             etcetera  	---	  0.0001
#               picket  	---	  0.0001
#               huevos  	---	  0.0001
#              verdict  	---	  0.0001
#               bomber  	---	  0.0001
#                bacon  	---	  0.0001
#                  snd  	---	  0.0001
#              breadth  	---	  0.0001
#                slush  	---	  0.0001
#             rambling  	---	  0.0001
#                  shi  	---	  0.0001
#          butteriness  	---	  0.0001
#                 hott  	---	  0.0001
#               phrank  	---	  0.0001
#                   ox  	---	  0.0001
#          underground  	---	  0.0001
#                mixer  	---	  0.0001
#             chu-toro  	---	  0.0001
#                 sono  	---	  0.0001
#                 menu  	---	  0.0001
#               watier  	---	  0.0001
#             westside  	---	  0.0001
#                drape  	---	  0.0001
#             chipotle  	---	  0.0001
#             tsukeman  	---	  0.0001
#             handicap  	---	  0.0001
#               voodoo  	---	  0.0001
#             agedashi  	---	  0.0001
#            diversion  	---	  0.0001
#           mayonnaise  	---	  0.0001
#               allure  	---	  0.0001
#           waterfront  	---	  0.0001
#               remain  	---	  0.0001
#                blend  	---	  0.0001
#                manor  	---	  0.0001
#
# topic 16:
#                 bias  	---	  0.0361
#             showcase  	---	  0.0282
#               liquid  	---	  0.0263
#             infinity  	---	  0.0212
#                dover  	---	  0.0166
#                 time  	---	  0.0149
#             patience  	---	  0.0121
#                 uhhh  	---	  0.0118
#              service  	---	  0.0107
#                  cal  	---	  0.0101
#               skanky  	---	  0.0095
#               person  	---	  0.0092
#                 vest  	---	  0.0076
#            landscape  	---	  0.0075
#                music  	---	  0.0074
#               search  	---	  0.0072
#                award  	---	  0.0070
#               hookah  	---	  0.0069
#              brownie  	---	  0.0065
#                 tide  	---	  0.0063
#                 tika  	---	  0.0062
#              peasant  	---	  0.0062
#                suede  	---	  0.0057
#             estrella  	---	  0.0056
#             bookmark  	---	  0.0054
#         extravaganza  	---	  0.0053
#                tator  	---	  0.0052
#             ambrosia  	---	  0.0050
#                drape  	---	  0.0050
#                slack  	---	  0.0049
#                stare  	---	  0.0049
#                  ala  	---	  0.0049
#             mattress  	---	  0.0047
#              stumble  	---	  0.0047
#                  lap  	---	  0.0045
#             reviewer  	---	  0.0044
#           motherland  	---	  0.0042
#             terminal  	---	  0.0042
#               bottle  	---	  0.0042
#                 todo  	---	  0.0042
#              riviera  	---	  0.0040
#                green  	---	  0.0040
#                 brew  	---	  0.0040
#              t-shirt  	---	  0.0036
#          underground  	---	  0.0035
#            yorkshire  	---	  0.0034
#               fiddle  	---	  0.0033
#            quotation  	---	  0.0032
#                 task  	---	  0.0032
#                 pong  	---	  0.0032
#               coffee  	---	  0.0032
#                great  	---	  0.0032
#               nachos  	---	  0.0031
#
# topic 17:
#               savory  	---	  0.0043
#                 bias  	---	  0.0042
#               liquid  	---	  0.0037
#                 nazi  	---	  0.0013
#                 menu  	---	  0.0013
#              service  	---	  0.0012
#                 spot  	---	  0.0012
#             showcase  	---	  0.0012
#                 time  	---	  0.0011
#                slack  	---	  0.0011
#                green  	---	  0.0011
#              peasant  	---	  0.0010
#               toilet  	---	  0.0010
#             chipotle  	---	  0.0010
#                  par  	---	  0.0009
#               hookah  	---	  0.0009
#             infinity  	---	  0.0009
#         extravaganza  	---	  0.0008
#             estrella  	---	  0.0008
#                stare  	---	  0.0008
#                 slaw  	---	  0.0007
#                drape  	---	  0.0007
#              verdict  	---	  0.0007
#               bummer  	---	  0.0007
#               fiddle  	---	  0.0006
#              stumble  	---	  0.0006
#             bookmark  	---	  0.0006
#               threat  	---	  0.0006
#                  sud  	---	  0.0006
#                   ox  	---	  0.0006
#               person  	---	  0.0006
#             etcetera  	---	  0.0006
#                 task  	---	  0.0006
#           motherland  	---	  0.0006
#                slush  	---	  0.0006
#                 vest  	---	  0.0005
#                 brew  	---	  0.0005
#             keyboard  	---	  0.0005
#                 tide  	---	  0.0005
#                 baby  	---	  0.0005
#       sustainability  	---	  0.0005
#                diego  	---	  0.0005
#             handicap  	---	  0.0005
#               thesis  	---	  0.0004
#             grouping  	---	  0.0004
#                music  	---	  0.0004
#             brandade  	---	  0.0004
#               quizno  	---	  0.0004
#                creme  	---	  0.0004
#              riviera  	---	  0.0004
#               infant  	---	  0.0004
#                 myth  	---	  0.0004
#               skanky  	---	  0.0004
#
# topic 18:
#               aspect  	---	  0.0177
#              samosas  	---	  0.0101
#                 bias  	---	  0.0089
#              removal  	---	  0.0075
#                 tofu  	---	  0.0074
#                lassi  	---	  0.0071
#             lobsicle  	---	  0.0050
#               liquid  	---	  0.0048
#            artichoke  	---	  0.0043
#                 riot  	---	  0.0042
#              fixture  	---	  0.0038
#                blank  	---	  0.0037
#               ceasar  	---	  0.0037
#               fiddle  	---	  0.0029
#               giggle  	---	  0.0029
#                  rou  	---	  0.0027
#                 time  	---	  0.0026
#             estrella  	---	  0.0026
#             etcetera  	---	  0.0025
#                   ox  	---	  0.0025
#              service  	---	  0.0024
#               victor  	---	  0.0024
#            destroyer  	---	  0.0023
#             cardamom  	---	  0.0018
#                go-to  	---	  0.0017
#             infinity  	---	  0.0017
#             humanity  	---	  0.0016
#         friendliness  	---	  0.0016
#          reminiscent  	---	  0.0016
#                  par  	---	  0.0014
#             chipotle  	---	  0.0014
#               virtue  	---	  0.0014
#              verdict  	---	  0.0014
#                 nook  	---	  0.0014
#               bummer  	---	  0.0014
#               dipper  	---	  0.0013
#              enought  	---	  0.0013
#            dungeness  	---	  0.0013
#                creme  	---	  0.0013
#                shiro  	---	  0.0012
#                 rice  	---	  0.0012
#                 menu  	---	  0.0012
#               hookah  	---	  0.0012
#             tamarind  	---	  0.0012
#                green  	---	  0.0012
#                dover  	---	  0.0011
#                  bow  	---	  0.0011
#                scone  	---	  0.0011
#                 vest  	---	  0.0011
#                fudge  	---	  0.0010
#              outside  	---	  0.0010
#              peasant  	---	  0.0010
#               skanky  	---	  0.0010
#
# topic 19:
#                 bias  	---	  0.0005
#               liquid  	---	  0.0004
#              service  	---	  0.0003
#             estrella  	---	  0.0003
#                 time  	---	  0.0003
#                 menu  	---	  0.0002
#                   ox  	---	  0.0002
#                  par  	---	  0.0002
#           motherland  	---	  0.0002
#             infinity  	---	  0.0002
#                 vest  	---	  0.0002
#                green  	---	  0.0002
#               hookah  	---	  0.0002
#                plate  	---	  0.0002
#               fiddle  	---	  0.0002
#              peasant  	---	  0.0002
#               person  	---	  0.0002
#                 brew  	---	  0.0002
#              penalty  	---	  0.0002
#               search  	---	  0.0002
#                slush  	---	  0.0002
#              hotties  	---	  0.0002
#              brownie  	---	  0.0002
#             keyboard  	---	  0.0002
#                  sud  	---	  0.0002
#               bottle  	---	  0.0002
#          bachlorette  	---	  0.0002
#                 slaw  	---	  0.0002
#               skanky  	---	  0.0002
#               bummer  	---	  0.0002
#                 wine  	---	  0.0002
#                drape  	---	  0.0002
#             etcetera  	---	  0.0002
#              abalone  	---	  0.0002
#                bacon  	---	  0.0002
#                slack  	---	  0.0002
#               bomber  	---	  0.0002
#             tsukeman  	---	  0.0002
#               watier  	---	  0.0002
#                dover  	---	  0.0002
#                 bang  	---	  0.0002
#               brioch  	---	  0.0002
#            warehouse  	---	  0.0002
#                tator  	---	  0.0002
#              stumble  	---	  0.0001
#             brandade  	---	  0.0001
#             accuracy  	---	  0.0001
#             babyback  	---	  0.0001
#               threat  	---	  0.0001
#              dryness  	---	  0.0001
#                 uhhh  	---	  0.0001
#              verdict  	---	  0.0001
#              riviera  	---	  0.0001
#
# topic 20:
#                 bias  	---	  0.0352
#               liquid  	---	  0.0277
#              service  	---	  0.0182
#                 time  	---	  0.0160
#             estrella  	---	  0.0152
#                 menu  	---	  0.0104
#                green  	---	  0.0094
#               hookah  	---	  0.0089
#                   ox  	---	  0.0088
#               fiddle  	---	  0.0087
#               bummer  	---	  0.0085
#             keyboard  	---	  0.0085
#           mozzerella  	---	  0.0084
#                 vest  	---	  0.0080
#              peasant  	---	  0.0071
#               person  	---	  0.0069
#                  par  	---	  0.0068
#             tsukeman  	---	  0.0066
#              riviera  	---	  0.0064
#              penalty  	---	  0.0062
#               bottle  	---	  0.0061
#                  fry  	---	  0.0060
#                 cous  	---	  0.0060
#               cherry  	---	  0.0060
#                 tini  	---	  0.0058
#           motherland  	---	  0.0057
#                slack  	---	  0.0056
#               skanky  	---	  0.0055
#                 task  	---	  0.0054
#              stumble  	---	  0.0053
#             chipotle  	---	  0.0053
#             bookmark  	---	  0.0053
#                diego  	---	  0.0051
#                 rice  	---	  0.0050
#                 roll  	---	  0.0049
#             etcetera  	---	  0.0048
#                 bang  	---	  0.0047
#             infinity  	---	  0.0046
#             brandade  	---	  0.0046
#              verdict  	---	  0.0045
#               watier  	---	  0.0043
#                stare  	---	  0.0043
#          underground  	---	  0.0043
#                dover  	---	  0.0042
#                drape  	---	  0.0041
#               search  	---	  0.0040
#                 curb  	---	  0.0040
#                 cali  	---	  0.0039
#               threat  	---	  0.0039
#       sustainability  	---	  0.0037
#                plate  	---	  0.0037
#              abalone  	---	  0.0037
#                  sud  	---	  0.0035
#
# topic 21:
#             chipotle  	---	  0.0018
#              verdict  	---	  0.0015
#               liquid  	---	  0.0013
#                 bias  	---	  0.0010
#                creme  	---	  0.0008
#              service  	---	  0.0008
#                 time  	---	  0.0006
#                   ox  	---	  0.0006
#             estrella  	---	  0.0005
#                green  	---	  0.0005
#                 menu  	---	  0.0005
#               person  	---	  0.0004
#                  sud  	---	  0.0004
#              gelatus  	---	  0.0004
#                 vest  	---	  0.0004
#                 task  	---	  0.0004
#              pinball  	---	  0.0004
#                  par  	---	  0.0003
#              peasant  	---	  0.0003
#           crustacean  	---	  0.0003
#           motherland  	---	  0.0003
#                diego  	---	  0.0003
#                stare  	---	  0.0003
#               hookah  	---	  0.0003
#                 baby  	---	  0.0003
#             keyboard  	---	  0.0003
#                 cous  	---	  0.0003
#             infinity  	---	  0.0003
#               brioch  	---	  0.0003
#               fiddle  	---	  0.0003
#          underground  	---	  0.0003
#                 rice  	---	  0.0003
#                 wine  	---	  0.0003
#               threat  	---	  0.0003
#                 yoly  	---	  0.0003
#               skanky  	---	  0.0003
#       sustainability  	---	  0.0003
#             bookmark  	---	  0.0003
#               bummer  	---	  0.0003
#            childhood  	---	  0.0003
#                drape  	---	  0.0003
#            headliner  	---	  0.0003
#                 roll  	---	  0.0003
#             peruvian  	---	  0.0003
#           conviction  	---	  0.0003
#                 comp  	---	  0.0003
#           spicy-ness  	---	  0.0003
#               savory  	---	  0.0002
#                slush  	---	  0.0002
#                dover  	---	  0.0002
#             brandade  	---	  0.0002
#               search  	---	  0.0002
#                 bang  	---	  0.0002
#
# topic 22:
#                 bias  	---	  0.0005
#               liquid  	---	  0.0005
#             estrella  	---	  0.0003
#                 time  	---	  0.0003
#              service  	---	  0.0003
#                green  	---	  0.0003
#               bummer  	---	  0.0003
#           motherland  	---	  0.0003
#               bottle  	---	  0.0002
#                 menu  	---	  0.0002
#                 vest  	---	  0.0002
#                   ox  	---	  0.0002
#                 poke  	---	  0.0002
#              abalone  	---	  0.0002
#                 slaw  	---	  0.0002
#             etcetera  	---	  0.0002
#             brandade  	---	  0.0002
#                plate  	---	  0.0002
#               threat  	---	  0.0002
#               fiddle  	---	  0.0002
#                 task  	---	  0.0002
#              peasant  	---	  0.0002
#             babyback  	---	  0.0002
#             bookmark  	---	  0.0002
#                  par  	---	  0.0002
#            diversion  	---	  0.0002
#           trattorium  	---	  0.0002
#               kaiser  	---	  0.0002
#               brioch  	---	  0.0002
#                 wine  	---	  0.0002
#                  sud  	---	  0.0002
#               person  	---	  0.0002
#               origin  	---	  0.0002
#               savory  	---	  0.0002
#                bacon  	---	  0.0002
#              hotties  	---	  0.0002
#             tsukeman  	---	  0.0002
#               cherry  	---	  0.0002
#                 cane  	---	  0.0002
#               skanky  	---	  0.0002
#                stare  	---	  0.0002
#               watier  	---	  0.0002
#                  fry  	---	  0.0002
#                 bang  	---	  0.0002
#                diego  	---	  0.0002
#              penalty  	---	  0.0002
#                slack  	---	  0.0002
#              stumble  	---	  0.0002
#          underground  	---	  0.0002
#                dover  	---	  0.0002
#             keyboard  	---	  0.0002
#               teppan  	---	  0.0002
#              verdict  	---	  0.0002
#
# topic 23:
#               liquid  	---	  0.0002
#                 bias  	---	  0.0002
#             infinity  	---	  0.0001
#              pumpkin  	---	  0.0001
#                tator  	---	  0.0001
#                  cal  	---	  0.0001
#                 time  	---	  0.0001
#                 guru  	---	  0.0001
#             marinate  	---	  0.0001
#                 room  	---	  0.0001
#              pastery  	---	  0.0001
#            delmonico  	---	  0.0001
#              regular  	---	  0.0001
#                 post  	---	  0.0001
#                 scam  	---	  0.0001
#                 chow  	---	  0.0001
#               flauta  	---	  0.0001
#                spent  	---	  0.0001
#                 ehhh  	---	  0.0001
#                  mud  	---	  0.0001
#               refund  	---	  0.0001
#                  hip  	---	  0.0001
#                black  	---	  0.0001
#                luigi  	---	  0.0001
#                  mis  	---	  0.0001
#               typing  	---	  0.0001
#             fritatta  	---	  0.0001
#          celebration  	---	  0.0001
#              cheesey  	---	  0.0001
#               buzzer  	---	  0.0001
#             smoother  	---	  0.0001
#             overtime  	---	  0.0001
#              service  	---	  0.0001
#                dance  	---	  0.0001
#              mexican  	---	  0.0001
#              a$$hole  	---	  0.0001
#              trooper  	---	  0.0001
#               cognac  	---	  0.0001
#                 oder  	---	  0.0001
#              believe  	---	  0.0001
#             patience  	---	  0.0001
#             antidote  	---	  0.0001
#               yummie  	---	  0.0001
#                 jane  	---	  0.0001
#               search  	---	  0.0001
#             headache  	---	  0.0001
#               voting  	---	  0.0001
#                glass  	---	  0.0001
#              spumoni  	---	  0.0001
#             let-down  	---	  0.0001
#              brownie  	---	  0.0001
#              washing  	---	  0.0001
#             sorority  	---	  0.0001
#
# topic 24:
#                 bias  	---	  0.0011
#               liquid  	---	  0.0010
#               savory  	---	  0.0009
#              service  	---	  0.0008
#                 menu  	---	  0.0006
#                 time  	---	  0.0005
#               fiddle  	---	  0.0005
#                  par  	---	  0.0005
#             tsukeman  	---	  0.0004
#             estrella  	---	  0.0004
#                slack  	---	  0.0004
#                 slaw  	---	  0.0004
#                 vest  	---	  0.0004
#             bookmark  	---	  0.0004
#           motherland  	---	  0.0004
#               bummer  	---	  0.0004
#             infinity  	---	  0.0004
#                 cous  	---	  0.0004
#             keyboard  	---	  0.0003
#             peruvian  	---	  0.0003
#             etcetera  	---	  0.0003
#                green  	---	  0.0003
#               hookah  	---	  0.0003
#                 brew  	---	  0.0003
#                   ox  	---	  0.0003
#                plate  	---	  0.0003
#              peasant  	---	  0.0003
#                 baby  	---	  0.0003
#              stumble  	---	  0.0003
#                slush  	---	  0.0003
#              sharing  	---	  0.0003
#                 tide  	---	  0.0003
#               marrow  	---	  0.0003
#               quizno  	---	  0.0003
#             patience  	---	  0.0003
#               bomber  	---	  0.0003
#               toilet  	---	  0.0003
#                 task  	---	  0.0003
#              penalty  	---	  0.0002
#         extravaganza  	---	  0.0002
#          underground  	---	  0.0002
#               threat  	---	  0.0002
#                stare  	---	  0.0002
#              riviera  	---	  0.0002
#                bacon  	---	  0.0002
#                  sud  	---	  0.0002
#                 poke  	---	  0.0002
#                 nazi  	---	  0.0002
#                  dig  	---	  0.0002
#                 bang  	---	  0.0002
#              snapper  	---	  0.0002
#                hotel  	---	  0.0002
#             babyback  	---	  0.0002
#
# topic 25:
# ...
#                diego  	---	  0.0005
#                 wine  	---	  0.0005
#                 comp  	---	  0.0005
#             peruvian  	---	  0.0005
#             keyboard  	---	  0.0005
#           spicy-ness  	---	  0.0005
#                stare  	---	  0.0005
#               skanky  	---	  0.0005
#                 cous  	---	  0.0005
#                slush  	---	  0.0005
#                 brew  	---	  0.0005
#                 slaw  	---	  0.0005
#                plate  	---	  0.0005
#              abalone  	---	  0.0005
#               kickin  	---	  0.0005
#              penalty  	---	  0.0005
#               bottle  	---	  0.0004
#        churrascarium  	---	  0.0004
#
# topic 62:
#                 bias  	---	  0.0008
#               liquid  	---	  0.0005
#             keyboard  	---	  0.0003
#               polish  	---	  0.0003
#                green  	---	  0.0003
#               skanky  	---	  0.0003
#                 rice  	---	  0.0003
#                   ox  	---	  0.0003
#                 time  	---	  0.0003
#             estrella  	---	  0.0003
#                  sud  	---	  0.0003
#              peasant  	---	  0.0003
#               bummer  	---	  0.0003
#              penalty  	---	  0.0002
#               origin  	---	  0.0002
#               threat  	---	  0.0002
#               person  	---	  0.0002
#              service  	---	  0.0002
#             brandade  	---	  0.0002
#                 menu  	---	  0.0002
#                chili  	---	  0.0002
#                 slaw  	---	  0.0002
#              gelatus  	---	  0.0002
#                drape  	---	  0.0002
#                plate  	---	  0.0002
#               recess  	---	  0.0002
#                 baby  	---	  0.0002
#                 vest  	---	  0.0002
#             jalapeno  	---	  0.0002
#              verdict  	---	  0.0002
#               muster  	---	  0.0002
#                 brew  	---	  0.0002
#          underground  	---	  0.0002
#              hotties  	---	  0.0002
#           trattorium  	---	  0.0002
#                stare  	---	  0.0002
#              tangine  	---	  0.0002
#            wallpaper  	---	  0.0002
#               cherry  	---	  0.0002
#                 poke  	---	  0.0002
#                 uhhh  	---	  0.0002
#             patience  	---	  0.0002
#                 lomi  	---	  0.0002
#                  par  	---	  0.0002
#               watier  	---	  0.0002
#            diversion  	---	  0.0002
#               fiddle  	---	  0.0002
#                slack  	---	  0.0002
#       sustainability  	---	  0.0002
#          cauliflower  	---	  0.0002
#              warrior  	---	  0.0002
#             schwarma  	---	  0.0002
#              glimmer  	---	  0.0002
#
# topic 63:
#               savory  	---	  0.0009
#                 bias  	---	  0.0008
#               liquid  	---	  0.0006
#             infinity  	---	  0.0005
#              service  	---	  0.0005
#                 time  	---	  0.0005
#                 wine  	---	  0.0004
#                 menu  	---	  0.0004
#                   ox  	---	  0.0003
#                 vest  	---	  0.0003
#                slack  	---	  0.0003
#           motherland  	---	  0.0003
#                green  	---	  0.0003
#               person  	---	  0.0003
#             estrella  	---	  0.0003
#               brioch  	---	  0.0003
#              peasant  	---	  0.0003
#               toilet  	---	  0.0003
#                 brew  	---	  0.0003
#               skanky  	---	  0.0003
#               quizno  	---	  0.0003
#                 nazi  	---	  0.0002
#                 spot  	---	  0.0002
#                  par  	---	  0.0002
#             babyback  	---	  0.0002
#                 task  	---	  0.0002
#               threat  	---	  0.0002
#                plate  	---	  0.0002
#               hookah  	---	  0.0002
#               thesis  	---	  0.0002
#             bookmark  	---	  0.0002
#                stare  	---	  0.0002
#                bacon  	---	  0.0002
#             grouping  	---	  0.0002
#             etcetera  	---	  0.0002
#                dover  	---	  0.0002
#                  sud  	---	  0.0002
#             chipotle  	---	  0.0002
#                diego  	---	  0.0002
#                tator  	---	  0.0002
#                  snd  	---	  0.0002
#                drape  	---	  0.0002
#               bomber  	---	  0.0002
#                 baby  	---	  0.0002
#          bachlorette  	---	  0.0002
#              penalty  	---	  0.0002
#                  fry  	---	  0.0002
#           date-night  	---	  0.0002
#                 slaw  	---	  0.0002
#             handicap  	---	  0.0002
#             accuracy  	---	  0.0002
#             ambrosia  	---	  0.0002
#         extravaganza  	---	  0.0002
#
# topic 64:
#             babyback  	---	  0.0563
#               circle  	---	  0.0220
#               brioch  	---	  0.0164
#             applebee  	---	  0.0130
#                 chap  	---	  0.0108
#               bouche  	---	  0.0081
#               liquid  	---	  0.0077
#                level  	---	  0.0073
#                 bias  	---	  0.0062
#            workplace  	---	  0.0059
#             accuracy  	---	  0.0057
#                   ox  	---	  0.0056
#             infinity  	---	  0.0055
#           motherland  	---	  0.0050
#               mignon  	---	  0.0049
#                plate  	---	  0.0040
#                 team  	---	  0.0038
#           instructor  	---	  0.0037
#               sprite  	---	  0.0033
#             estrella  	---	  0.0033
#              service  	---	  0.0032
#                mixed  	---	  0.0032
#           loveliness  	---	  0.0032
#                 dine  	---	  0.0029
#          bachlorette  	---	  0.0029
#           discomfort  	---	  0.0029
#                 menu  	---	  0.0029
#                 time  	---	  0.0028
#                wrist  	---	  0.0028
#                  jay  	---	  0.0028
#                 wine  	---	  0.0026
#                 brew  	---	  0.0026
#              peasant  	---	  0.0026
#               bummer  	---	  0.0026
#                  ham  	---	  0.0025
#                 vest  	---	  0.0025
#              abalone  	---	  0.0025
#                  fav  	---	  0.0025
#             sidenote  	---	  0.0025
#          vinaigrette  	---	  0.0025
#                jigae  	---	  0.0023
#             musician  	---	  0.0023
#               tomato  	---	  0.0023
#               hookah  	---	  0.0022
#                 tuna  	---	  0.0022
#               skanky  	---	  0.0022
#                draft  	---	  0.0021
#             settling  	---	  0.0021
#                bacon  	---	  0.0021
#                 bang  	---	  0.0021
#               arepas  	---	  0.0021
#                  snd  	---	  0.0020
#                 goto  	---	  0.0019
#
# topic 65:
#               liquid  	---	  0.0004
#                 bias  	---	  0.0004
#              service  	---	  0.0003
#               threat  	---	  0.0003
#                 menu  	---	  0.0002
#             estrella  	---	  0.0002
#           motherland  	---	  0.0002
#                  sud  	---	  0.0002
#                green  	---	  0.0002
#                 time  	---	  0.0002
#                bacon  	---	  0.0002
#               bottle  	---	  0.0002
#                 slaw  	---	  0.0002
#             bookmark  	---	  0.0002
#                slack  	---	  0.0002
#              hotties  	---	  0.0002
#             etcetera  	---	  0.0002
#               bummer  	---	  0.0002
#                   ox  	---	  0.0002
#              peasant  	---	  0.0002
#               bomber  	---	  0.0002
#              penalty  	---	  0.0002
#               fiddle  	---	  0.0002
#                 vest  	---	  0.0002
#             chipotle  	---	  0.0002
#                  par  	---	  0.0002
#               marrow  	---	  0.0002
#                 task  	---	  0.0002
#                diego  	---	  0.0002
#               person  	---	  0.0002
#                 poke  	---	  0.0002
#              abalone  	---	  0.0002
#               hookah  	---	  0.0002
#                 wine  	---	  0.0002
#               savory  	---	  0.0002
#             keyboard  	---	  0.0002
#                 bang  	---	  0.0002
#            diversion  	---	  0.0002
#               watier  	---	  0.0002
#              riviera  	---	  0.0002
#             brandade  	---	  0.0002
#              verdict  	---	  0.0002
#             infinity  	---	  0.0002
#                 brew  	---	  0.0002
#          underground  	---	  0.0002
#             babyback  	---	  0.0002
#             somethin  	---	  0.0002
#             tsukeman  	---	  0.0002
#                plate  	---	  0.0002
#           chandelier  	---	  0.0001
#               whisky  	---	  0.0001
#               brioch  	---	  0.0001
#                wrath  	---	  0.0001
#
# topic 66:
#                 bias  	---	  0.0043
#               liquid  	---	  0.0043
#                 time  	---	  0.0018
#              service  	---	  0.0017
#           motherland  	---	  0.0016
#             infinity  	---	  0.0015
#             estrella  	---	  0.0013
#                  sud  	---	  0.0013
#             babyback  	---	  0.0013
#             bookmark  	---	  0.0013
#               brioch  	---	  0.0013
#               savory  	---	  0.0012
#                   ox  	---	  0.0012
#                 menu  	---	  0.0012
#               bummer  	---	  0.0012
#               skanky  	---	  0.0011
#                 bang  	---	  0.0011
#                 vest  	---	  0.0010
#                tator  	---	  0.0010
#              peasant  	---	  0.0010
#                 brew  	---	  0.0010
#               hookah  	---	  0.0010
#               person  	---	  0.0009
#                plate  	---	  0.0009
#                green  	---	  0.0009
#              abalone  	---	  0.0009
#                 task  	---	  0.0008
#             keyboard  	---	  0.0008
#              riviera  	---	  0.0007
#                stare  	---	  0.0007
#             applebee  	---	  0.0007
#                dover  	---	  0.0007
#              stumble  	---	  0.0007
#                slack  	---	  0.0007
#                  par  	---	  0.0007
#               fiddle  	---	  0.0007
#               search  	---	  0.0006
#             accuracy  	---	  0.0006
#           discomfort  	---	  0.0006
#                bacon  	---	  0.0006
#               cherry  	---	  0.0006
#          underground  	---	  0.0006
#             etcetera  	---	  0.0006
#            quotation  	---	  0.0006
#               bottle  	---	  0.0005
#                 chap  	---	  0.0005
#             brandade  	---	  0.0005
#              tangine  	---	  0.0005
#               threat  	---	  0.0005
#                  snd  	---	  0.0005
#                 wine  	---	  0.0005
#              penalty  	---	  0.0005
#          bachlorette  	---	  0.0005
#
# topic 67:
#                 bias  	---	  0.0008
#               savory  	---	  0.0007
#               liquid  	---	  0.0006
#              service  	---	  0.0004
#                 time  	---	  0.0004
#             infinity  	---	  0.0003
#                 menu  	---	  0.0003
#           motherland  	---	  0.0003
#             bookmark  	---	  0.0002
#                  par  	---	  0.0002
#                slack  	---	  0.0002
#                 nazi  	---	  0.0002
#                   ox  	---	  0.0002
#             etcetera  	---	  0.0002
#                 spot  	---	  0.0002
#               brioch  	---	  0.0002
#               toilet  	---	  0.0002
#                 brew  	---	  0.0002
#               person  	---	  0.0002
#               bummer  	---	  0.0002
#               hookah  	---	  0.0002
#                tator  	---	  0.0002
#                  sud  	---	  0.0002
#               skanky  	---	  0.0002
#               quizno  	---	  0.0002
#               bomber  	---	  0.0002
#             brandade  	---	  0.0002
#              penalty  	---	  0.0002
#              peasant  	---	  0.0002
#                green  	---	  0.0002
#                stare  	---	  0.0002
#                slush  	---	  0.0002
#             estrella  	---	  0.0002
#                plate  	---	  0.0002
#                dover  	---	  0.0002
#                 vest  	---	  0.0002
#          underground  	---	  0.0002
#                  snd  	---	  0.0002
#               fiddle  	---	  0.0002
#              stumble  	---	  0.0002
#       sustainability  	---	  0.0002
#             babyback  	---	  0.0002
#                 slaw  	---	  0.0002
#               watier  	---	  0.0002
#                drape  	---	  0.0002
#                 bang  	---	  0.0002
#                bacon  	---	  0.0002
#             applebee  	---	  0.0002
#               threat  	---	  0.0002
#            newspaper  	---	  0.0002
#              riviera  	---	  0.0002
#              rellena  	---	  0.0002
#              hotties  	---	  0.0002
#
# topic 68:
#                 bias  	---	  0.0014
#               liquid  	---	  0.0014
#             estrella  	---	  0.0007
#           motherland  	---	  0.0007
#                 time  	---	  0.0007
#               brioch  	---	  0.0007
#                   ox  	---	  0.0006
#             babyback  	---	  0.0006
#               hookah  	---	  0.0006
#               bummer  	---	  0.0005
#              abalone  	---	  0.0005
#                plate  	---	  0.0005
#                 brew  	---	  0.0005
#              service  	---	  0.0004
#             bookmark  	---	  0.0004
#                 vest  	---	  0.0004
#               skanky  	---	  0.0004
#                green  	---	  0.0004
#             infinity  	---	  0.0004
#                tator  	---	  0.0004
#              penalty  	---	  0.0004
#                  par  	---	  0.0004
#               person  	---	  0.0004
#                 menu  	---	  0.0003
#             accuracy  	---	  0.0003
#               cherry  	---	  0.0003
#              peasant  	---	  0.0003
#             applebee  	---	  0.0003
#                 wine  	---	  0.0003
#                 chap  	---	  0.0003
#          vinaigrette  	---	  0.0003
#                stare  	---	  0.0003
#                suede  	---	  0.0003
#                 team  	---	  0.0003
#                bacon  	---	  0.0003
#                 bang  	---	  0.0003
#                 task  	---	  0.0003
#              stumble  	---	  0.0003
#                dover  	---	  0.0003
#               bottle  	---	  0.0003
#                  snd  	---	  0.0003
#             keyboard  	---	  0.0003
#                diego  	---	  0.0003
#               fiddle  	---	  0.0003
#                  fry  	---	  0.0003
#               noodle  	---	  0.0003
#                slack  	---	  0.0003
#                glass  	---	  0.0003
#                slush  	---	  0.0003
#                 cane  	---	  0.0003
#                drape  	---	  0.0003
#               bomber  	---	  0.0002
#             brandade  	---	  0.0002
#
# topic 69:
#                sisig  	---	  0.0071
#               liquid  	---	  0.0060
#                 bias  	---	  0.0059
#           waitperson  	---	  0.0030
#               rookie  	---	  0.0030
#                 time  	---	  0.0029
#                green  	---	  0.0023
#             estrella  	---	  0.0022
#              penalty  	---	  0.0020
#              service  	---	  0.0019
#               bummer  	---	  0.0017
#           motherland  	---	  0.0016
#               hookah  	---	  0.0016
#               plasma  	---	  0.0016
#                 menu  	---	  0.0015
#              peasant  	---	  0.0014
#                 emmy  	---	  0.0014
#               fiddle  	---	  0.0014
#               skanky  	---	  0.0013
#                   ox  	---	  0.0013
#             bookmark  	---	  0.0013
#                  par  	---	  0.0013
#                 vest  	---	  0.0013
#               person  	---	  0.0013
#             babyback  	---	  0.0013
#              riviera  	---	  0.0012
#             infinity  	---	  0.0012
#               savory  	---	  0.0012
#              abalone  	---	  0.0012
#               brioch  	---	  0.0012
#             keyboard  	---	  0.0012
#                  sud  	---	  0.0011
#                slack  	---	  0.0011
#                 brew  	---	  0.0011
#                scale  	---	  0.0010
#               search  	---	  0.0010
#                 cous  	---	  0.0010
#                 task  	---	  0.0010
#              stumble  	---	  0.0009
#                 bang  	---	  0.0009
#                drape  	---	  0.0009
#              pinball  	---	  0.0009
#                stare  	---	  0.0009
#               cherry  	---	  0.0008
#                  fry  	---	  0.0008
#                plate  	---	  0.0008
#             filipino  	---	  0.0008
#             etcetera  	---	  0.0008
#                diego  	---	  0.0008
#               seller  	---	  0.0008
#               marrow  	---	  0.0008
#                bacon  	---	  0.0007
#         extravaganza  	---	  0.0007

# %%
gamma.shape
# Out:
# (50, 70)

# %%
def kl_div_sym(v1,v2):
    n.sum(v*)
