# %%
# %matplotlib inline
import numpy as np
import scipy as sp
import matplotlib as mpl
import matplotlib.cm as cm
import matplotlib.pyplot as plt
import pandas as pd
pd.set_option('display.width', 500)
pd.set_option('display.max_columns', 100)
pd.set_option('display.notebook_repr_html', True)
import seaborn as sns
sns.set_style("whitegrid")
sns.set_context("poster")

# %% [markdown]
# In this notebook, we process the reviews from the dataset. The goal is to merge reviews by restaurants and transform these super reviews into a list of common nouns. The parsing function is inspired by a Data Science (cs109) homework:

# %%
import json
data = []
with open("../cs281_data/yelp_dataset_challenge_academic_dataset/yelp_academic_dataset_business.json") as f:
    for l in f:
        data.append(json.loads(l))

# %%
business_list = []
    
for b in data:
    d = b.copy()
    
    # Dropping unconsidered features
    d.pop('hours')
    #d.pop('attributes')
    d.pop('neighborhoods')
    d.pop('type')
    d.pop('full_address')
    d.pop('name')    
    
    business_list.append(d)
    
business=pd.DataFrame(business_list)
# Changing the index
business = business.set_index('business_id')

business.head(20)
# Out:
#                                                                attributes                                         categories         city   latitude   longitude   open  review_count  stars state
# business_id
# vcNAWiLM4dR7D2nwwJ7nCA                     {u'By Appointment Only': True}                        [Doctors, Health & Medical]      Phoenix  33.499313 -111.983758   True             9    3.5    AZ
# UsFtqoBl7naz8AVUBZMjQQ  {u'Happy Hour': True, u'Accepts Credit Cards':...                                        [Nightlife]   Dravosburg  40.350519  -79.886930   True             4    3.5    PA
# cE27W9VPgO88Qxe4ol6y_g                           {u'Good for Kids': True}                     [Active Life, Mini Golf, Golf]  Bethel Park  40.356896  -80.015910  False             5    2.5    PA
# HZdLhv6COCleJMo7nPl-RA                                                 {}  [Shopping, Home Services, Internet Service Pro...   Pittsburgh  40.357620  -80.059980   True             3    3.5    PA
# mVHrayjG3uZ_RLHkLj-AMg  {u'Alcohol': u'full_bar', u'Noise Level': u'av...  [Bars, American (New), Nightlife, Lounges, Res...     Braddock  40.408735  -79.866351   True            11    4.5    PA
# KayYbHCt-RkbGcPdGOThNg  {u'Alcohol': u'full_bar', u'Noise Level': u'lo...  [Bars, American (Traditional), Nightlife, Rest...     Carnegie  40.415517  -80.067534   True            15    4.0    PA
# b12U9TFESStdy7CsTtcOeg                                                 {}                          [Auto Repair, Automotive]     Carnegie  40.394588  -80.084454   True             5    1.5    PA
# Sktj1eHQFuVa-M4bgnEh8g                           {u'Good for Kids': True}                           [Active Life, Mini Golf]     Carnegie  40.405404  -80.076267   True             4    4.0    PA
# 3ZVKmuK2l7uXPE6lXY4Dbg                                                 {}                       [Home Services, Contractors]     Carnegie  40.406324  -80.090357   True             3    2.5    PA
# wJr6kSA5dchdgOdwH6dZ2w  {u'Take-out': True, u'Drive-Thru': False, u'Ou...  [Burgers, Breakfast & Brunch, American (Tradit...     Carnegie  40.387732  -80.092874   True             8    3.5    PA
# yXuao0pFz1AxB21vJjDf5w  {u'Price Range': 3, u'Accepts Credit Cards': T...                                    [Food, Grocery]     Carnegie  40.387732  -80.092874   True             3    3.5    PA
# fNGIbpazjTRdXgwRY_NIXA  {u'Alcohol': u'full_bar', u'Noise Level': u'av...  [Bars, American (Traditional), Nightlife, Loun...     Carnegie  40.396469  -80.084942   True             5    4.0    PA
# b9WZJp5L1RZr4F1nxclOoQ  {u'Alcohol': u'none', u'Noise Level': u'averag...                  [Breakfast & Brunch, Restaurants]     Carnegie  40.396744  -80.084800   True            38    4.5    PA
# zaXDakTd3RXyOa7sMrUE1g  {u'Take-out': True, u'Price Range': 1, u'Outdo...                               [Cafes, Restaurants]     Carnegie  40.404638  -80.089985   True             5    4.0    PA
# zgy27FSnvwdINfk5cXBIyQ  {u'Accepts Credit Cards': True, u'Wi-Fi': u'fr...  [Hotels & Travel, Event Planning & Services, H...     Carnegie  40.417419  -80.088557   True             5    4.0    PA
# WETE_LykpcnrC1sFcQ5EGg  {u'Take-out': True, u'Price Range': 2, u'Outdo...        [Pubs, Irish, Nightlife, Bars, Restaurants]     Carnegie  40.408670  -80.085279  False             6    3.5    PA
# 6o3RK6rTcN3nw-j-r2nQmA                                                 {}                                                 []     Carnegie  40.408568  -80.084992   True             4    2.5    PA
# woOVJ0Z2f6XNCDntHA3b_g                   {u'Accepts Credit Cards': False}             [Local Services, Sewing & Alterations]     Carnegie  40.407889  -80.086060   True             5    5.0    PA
# rv7CY8G_XibTx82YhuqQRw  {u'Take-out': True, u'Accepts Credit Cards': T...                                      [Restaurants]     Carnegie  40.386891  -80.093704   True             3    3.5    PA
# e_U_FnpdKVgNb4mUN2cU_Q                     {u'By Appointment Only': True}    [Health & Medical, Dentists, General Dentistry]     Carnegie  40.390760  -80.078657   True             6    2.0    PA

# %%
Lasvegas = np.array(business.city[business.city=='Las Vegas'].index.values,dtype=str)

# %%
lvr = []
for i in Lasvegas:
    if i in rest:
        lvr.append(i)

# %%
import json
review = []
with open("../cs281_data/yelp_dataset_challenge_academic_dataset/yelp_academic_dataset_review.json") as f:
    for r in f:
        review.append(json.loads(r))

# %%
count = 0 
for r in review:
    if r['business_id'] in lvr:
        count += 1

# %%
count

# %%
rest = np.load('temp/restaurants_index.npy')

# %%
business_ids = [r['business_id'] for r in review]

# %%
combined_review_dic = dict.fromkeys(list(set(business_ids)))
business_ids_tuples = zip(range(len(business_ids)),business_ids)
for tup in business_ids_tuples:
    if combined_review_dic[tup[1]] is None:
        combined_review_dic[tup[1]] = [review[tup[0]]['text'],[review[tup[0]]['stars']]]
    else:
        combined_review_dic[tup[1]][0] = " ".join([combined_review_dic[tup[1]][0], review[tup[0]]['text']])
        (combined_review_dic[tup[1]][1]).append(review[tup[0]]['stars'])

# %%
restaurant_reviews_lasvegas = {}
for r in rest:
    if r in Lasvegas:
        restaurant_reviews_lasvegas[r] =  combined_review_dic[r]

# %%
restaurant_reviews_lasvegas.keys()
# Out:
# [u'YnIzXtsgQdBy3WtjzOaQMA',
#  u'8buIr1zBCO7OEcAQSZko7w',
#  u'81dvu5TkKxzm-UWsD9OC-g',
#  u'3bwxfBvKABepxYWGz3pHXA',
#  u's5yzZITWU_RcJzWOgjFecw',
#  u'NMi9cy9lwAloyW2SQIKoMw',
#  u'buUNo4XhN5TBGT50LqkPHw',
#  u'PhE7XCfBJLDRswoc8OfqUw',
#  u'Ft2G2rrmtM5WwVRssrQZNg',
#  u'FDfK4HygC_P-Idoy_K8PKQ',
#  u'yghonKu_3q4Iu08HbNsyOQ',
#  u'onItgedmKDLbI3JHOE5XTA',
#  u'R_os9qwoga12ksSzAwZdoA',
#  u'G2zrrc65AeqPtE5wymvIww',
#  u'nZww1gdBAi9HtRKiQHL2qA',
#  u'GN72XbUh61J5wWQyW2oZsQ',
#  u'MKUT42AO_eLq0Av-PvQC7A',
#  u'q5IWRPqeOhj1WygZ1Dcfbw',
#  u'cjYOxsZKTcq47tdR5CF8Hw',
#  u'MgMh64Y-gfu7pnak0oqF7g',
#  u'qTE9glo2Q_-D7nV-4xcyew',
#  u'yJDSMugu_Pom3pJE8MRrJA',
#  u'sih8j621A66QoiUFues5qQ',
#  u'KWowrYsqiSITwogfi99djQ',
#  u'PDbx8YH-AHKA4drZvfhKOg',
#  u'BgnXX6NAMzL4tXES5FAadw',
#  u'wE_exQZBL8sMy2DilI5qAQ',
#  u'MR3-Ll-hoUGZMA-B1MTgGQ',
#  u'pwF_phwjD1ZHsY1xC9H7mA',
#  u'abN3TI-6TkzvdjeOCjXawQ',
#  u'BUFZGU2ux-JIGIozzdDiwQ',
#  u'gWRJ_Zyl2gtx_pCNTKnG2A',
#  u'qKvkpUoDuYIwPNuldwzUtg',
#  u'3GnkK4g6XHL2BbIQ7LhfAQ',
#  u'b248eH4DPvnWHq3h_BqHVg',
#  u'iixLYn4-HwBUvgS4wQmQKQ',
#  u'Rck6ZPLpkIdmQvDPRiNEpA',
#  u'IdpMuPyKIEfO41IlLxXwmw',
#  u'8ezD9Q-jRLNXbQd1nRceFQ',
#  u'MhgYfihkb1QZfVpSNLb2uA',
#  u'n30q_HaFRWmjFR_bXh9_dg',
#  u'tCXIc3z5epTRqlZPqhPqsQ',
#  u'M1xG7umlR-jalgYSxuPLYQ',
#  u'Fb__zkvQX3W7u1A72h4wPw',
#  u'd-RORs3TaBgYgBb0tLzMIA',
#  u'atzOrsnL_2pL6OttGbgUeA',
#  u'atLmZg76uDg0oKhKjHLMyg',
#  u'ZP6qFq7LUh6Tr7WHPoOW6g',
#  u'9XOzi2IIibwtnGOvtdDpjA',
#  u'dRejAgrPIwD6AcykS5Re9g',
#  u'f6KGn2OyYk6LWEpnUEgerw',
#  u'jWGm_Wol4qHyi6OHv2dqUA',
#  u'abyw7M9utpZJGo_RF0LScQ',
#  u'nuHftEWNyMIsa4R4OpqlQg',
#  u'LjW3-zIl9z8JGrPe6ub0ng',
#  u'NYufiY89993XQ2uQ1VzP2Q',
#  u'FAencdv8yZkYi1YGdX1dcw',
#  u'jnGp9K2AsLFKF3ogfUxsnA',
#  u'3wuzMFwVbbLCffN3gpikOQ',
#  u'FopM8p0F77scg5ioX2vldA',
#  u'FwYIyHrdkkB28wbbEDJ9Hg',
#  u'YkRwenPlQRloPFOX5l-iEA',
#  u'vIPDzACROxW2O3ZwR25ChQ',
#  u'd-WxJAsK8DWE9lBK2PVAfA',
#  u'jBIMDAwgJ57GUsI9xy4wEw',
#  u'0oz45sNYYP2LKKBjNTD2yA',
#  u'vN_Dpq_67Um_AA1agBDs3w',
#  u'ritiYLxY_Pw8wYz38-eBKw',
#  u'6gjfXqaxZgv0C2aHyl4yuQ',
#  u'gq7u9uyOkpLCeh_lxR-WFw',
#  u'FCjv7fiz3VK-T-0X4q228g',
#  u'a2_T-Zw2FK-r9anByMaE_w',
#  u'PmeN_flCu1DonjP_g90sFw',
#  u'6ZaA_KOS1wW5PqDPAHH9Qg',
#  u'BTSigmp5qWH2Fq9-xJETzw',
#  u'rGvkljWlP7ysvLEUucoyqA',
#  u'Z9EbmrRhhrkUTiGdnHxYaQ',
#  u'H-nlydkvuHBlsk4aJzCAYQ',
#  u'LdBOo8U_ygMIw1lfSJwoUg',
#  u'GAA2AxjySMqN-p-n89SJIA',
#  u'kePxkm183BDiOiDcsjgAhg',
#  u'zt1TpTuJ6y9n551sw9TaEg',
#  u'keV-NU5jaemf9L_7HDX-OA',
#  u'QB4VxZP5ixv0RN118bpcag',
#  u'cXciYOqcntGXoP4rHkvnDw',
#  u'y6sNNP97UCSl_p2o5Wm40A',
#  u'xD8Q42kqjsxiUcs_trdLgg',
#  u'cKL_n9FpPaYHNDb_JLCLGw',
#  u'O-_kxBV_IYdKlG98iqjQjw',
#  u'k5B4cVNS2CVcPo8_j5M4fg',
#  u'DISyf3MjqNqGVZE2hgmcoA',
#  u'-hR0gDq8FD2DJI6eJX7U1A',
#  u'GwGDLjbNf6d71QNOmY1OBQ',
#  u'lvXTTRMIlSCZ8uOgRg6s9g',
#  u'-PESvVv3rPQFAU1_cZ8_hw',
#  u'P6HbQnaNOqp9MDgrmbUTRQ',
#  u'WgsKcV4zZ2JnxUj9lKdn9Q',
#  u'sXEOGcIGsO2_zZXYxVadTw',
#  u'TUxCIJ6Jj2lEOqoVIoUH4g',
#  u'gWZMV5q8CSp8K5tZcMokCA',
#  u'7zlhizyTYUTqAqQz6w416A',
#  u'XhAdgKPia6GwUqSNZlL4GQ',
#  u'trC8BtTuNJniFaCaK1IQ4w',
#  u'nqUg5UdPVwNABqaM4iuXsw',
#  u'6gJj6LSZY5HsOhaYpIvQxw',
#  u'j4TMayffJHao9Ntd799Bhg',
#  u'InsT_8VUeBpLGupKuQAlQg',
#  u'0w46K_07XbKvCMe8qV6Qow',
#  u'N_mLuCdN1wbY86Xt0DivcQ',
#  u'loynWw80wC_Tc2Q9iV8y9Q',
#  u'DWg_KpDIeHX01e1l1i5TnQ',
#  u'8hnjKa0-bQtvbESv51LoFQ',
#  u'vPFiYlgyTpoqonN3rZkJhg',
#  u'DAha3IRYbGJh0UbvMHJ77w',
#  u'kE7hkm4gn8dHvGFwqy6foQ',
#  u'OlKX_FAE38BjfKsyjLQF5A',
#  u'rAZglrxLotA9xaa7KPXV5g',
#  u'xaM-mowHi-_sFXEztXnu7g',
#  u'4Bjn6QdaJIvsmcspcucOkA',
#  u'a1t31qMLd5fQocEjbSJ61A',
#  u'-nRgJjyPsNiPMhBTdTvwrA',
#  u'C9EmitKfcW6IuqA8mQKt1g',
#  u'jJJRYzEylibIkck8qOUNrg',
#  u'CBoMK_j_QG-DdMIsqznTkQ',
#  u'Q5pTGQKEhxgit1fwgrHEbg',
#  u'xXJ_ZUiTGdT6T3PpnaKxTg',
#  u'tLwU1rOIqNmaP7e8e-0VEA',
#  u'm-akXro6GMgJt627Hc1rGA',
#  u'lidcKZMOzz9M2p7-SznZcA',
#  u'QD8wcMoJ7YPBCA5uKA27zg',
#  u'bqYrEwL5xjqv0u8XAij--Q',
#  u'Qher1XRFuU8GnhA4BH7wog',
#  u'tv3qQk43GgNRxhu5LK2HXw',
#  u'hisG5g4wayOJFjI6QjsH9w',
#  u'r_vPmyreFW58n3goXqv1kQ',
#  u'DRMwvfM0fg-GY4hD5P9apA',
#  u'L-NzaroskDG7cwW9OJJadw',
#  u'I2rMZ5t1WliK5PaGxakBUA',
#  u'scbkHTbGTOA4xOrRcU3bBw',
#  u'54_mej5zTsyf9KoohdA3hg',
#  u'AYbUb5UcAngroJ6uJG7tLQ',
#  u'aBQZx0tUdFvsZ5kAMR-eWQ',
#  u'PJoiSHK9Pf9BNKf_xB9gFA',
#  u'VAEUkY_a_p94bT3Gnf4FDg',
#  u'8SkoyQ3iHXECEit2BDwBrw',
#  u'DabtJLx6Aw5BTTda8EdnKA',
#  u'WM6uXQWAWgsM9YqXLZGMUw',
#  u'tw6GRnK752GAl3ylfjuRuQ',
#  u'3cSnc2Ts0GckC9QRvlQbKA',
#  u'dF-u2E0ZFAZMlAlsTjHz2A',
#  u'guvpuXC3EmOWyTR2reeQqw',
#  u'ddFOdjlQ_uagpDk6w_a5jw',
#  u'jjChNLJnXbtPlxJW3hVi5A',
#  u'EByOF2mfGDvOYorPOCJW2Q',
#  u'Hv2GCCnyRRo2XxF9XJpK6g',
#  u'fiSbGmzv57BPNDr8HL2wyA',
#  u'OrTArReTvdVxEKBAxsz3Ww',
#  u'modnOTYDsotSTmWKXBJvpA',
#  u'7P9k2NQPeIyF1TkH5cKQVg',
#  u'gjWHlIXMPFDTXCWVrFtjTg',
#  u'yEvkmoIBNHfYI6IcjLcx7g',
#  u'8eIMOGbQqtyVZ_w-nHif2w',
#  u'52ThhgAweE-ZOhj8ugjS0w',
#  u'Z0kyK8wCBNGkkUT9UrMWcg',
#  u'K9Bv1h5BQPXZFl2Q0FnXrw',
#  u'qLa_684GMvVfR4WNHshQSA',
#  u'_aRnypLaHgZ7E9wZqHilOg',
#  u'Lfjh90yNwBiUIGmVwM4ImA',
#  u'oq7mXtz0Klb_QlqBjmcdaw',
#  u'8Eh-lPCEXfGP72gQTct-lw',
#  u'XKI-Wu5BMTp4HZy6k7FBmg',
#  u'yhLbKlT5sRq4RRwYjhJt6w',
#  u'sD38Tp5O4W06Bx-DxeW9oQ',
#  u'kiA-L7r9uHh2bqUPxuCzNQ',
#  u'ecI5Vq2uEMbFbZIHOBosYw',
#  u'-ILeXEbL98YCJ6Me82O7Rg',
#  u'wQgdpcqcA0HgDVZvrOk7Yw',
#  u'ZZcKMWza1-GqrmhzFHW_mw',
#  u'0Wu4-E2NKM-H8Yt7zZ-cxw',
#  u'uCx8VZw2oiAdi7wFnoPs-w',
#  u'76jf1_2bJCpnF33ZrAgGgA',
#  u'NG1p4b7a83krNyX08ssPTQ',
#  u'2dioqPw6txEgB397frYg-A',
#  u'LM71VvmoAWDD5z8h7XoVig',
#  u'wZIryTDCEYtUvUqIGY9hPA',
#  u'47Q_CDw7-MDeDNCJMtQOUQ',
#  u'10GBdcrKBSL1QFnkXWjfjQ',
#  u'VlWAXFH5mqzQA9QNt_Azug',
#  u'Oqb-MBYAmYUJLKwbwpQUEQ',
#  u'0FmQpDFbWRIPHYBInCTwlg',
#  u'1dnarzaw3bwFrK38hldi_Q',
#  u'xtuiOHwL5HmVINb9XZvc9g',
#  u'ywwnswdMkIjYj46qLsNG2w',
#  u'YVmP0J7WjYKvbhAknWIUaw',
#  u'_Ck4AAtkBLsDL9Qcbo9h1Q',
#  u'unxjJu6JOxVKwGTVdtaXMQ',
#  u'aYAlzKHwXQn6JNLweRnZjQ',
#  u'j0Cwi0GmIFEC5g9lHmWb-A',
#  u'mo-zc81Q52d-iz5Put3zzw',
#  u'VnR-KYOHlQX-aFMkaY686Q',
#  u'BH4ky1-owYRtIKRZ0bw9Rw',
#  u'OWfB7JDng-pgVq31gqzu4g',
#  u'P8DQlNd4ZVCtxFsH_QARFQ',
#  u'2-XO3LwWdpm-_xOUHSAqGQ',
#  u'YZuHOgbKiP3dN4_ROOUyDQ',
#  u'Ny2xALovpv-ZbTvwSSB86A',
#  u'Ai228_UNO8NjDcWogwgO6g',
#  u'J_Z_XLjhhtTNOupOwemDqg',
#  u'5yUB8II4URDJhwCUT1l-qg',
#  u'-7PWVPeSkUulZV0KrGysUQ',
#  u'jOgSvW9VNw0Cw9p8w5A2JQ',
#  u'D4AsRDOllNDR65PBNRfUMQ',
#  u'xHcysG66ED8lE2h27CJ3hg',
#  u'RSWWZGGU4JpCYgr2yASEWw',
#  u'Kma0nPwuWfqelROxRIwLRw',
#  u'3RKhnCtiN6jfaSbJU-9kmA',
#  u'OzZhMnqlW87Vw9wnhnIlkg',
#  u'JBtHmLIXJprdHV2xMa0KKQ',
#  u'5FPU_0VSLtR2yY7IQzaH5g',
#  u'PD7RkTtCL-P43EEfeIDKyA',
#  u'2FurIZ1RmC9HndCQJAZJKA',
#  u'8X_9ue_Hnpr1lYa90EG3bw',
#  u'kUtoL4B9BBVgViPHk9B8EQ',
#  u'6dLJtcFfD2kBbrOd42KHsQ',
#  u'jmgKs7CTqSWWwJnFnPIf4A',
#  u'qXOAl1zrwUufSGlUWGvA2A',
#  u'bfxwldnm7izbQpz4gj3Cdg',
#  u'zFbQ-8AvAIM1tQoqIh_sew',
#  u'vFaPBgGiocYc0f9rugZ5-w',
#  u'0lQDOFqEVB1LQhkS2kN1RA',
#  u'wKggm6YQQnHlHSnRyXrPhw',
#  u'XqpUYK7tjHe_gi0BrNf1sw',
#  u'qWjnmSZPWvf_Pv_IW5Y0KA',
#  u'FV16IeXJp2W6pnghTz2FAw',
#  u'8RYf6xuRZDTyvX59eTAydw',
#  u'AjZLGVy8GgpdCCXCtCXV_A',
#  u'MXqmV0513hptrtjihDdf3Q',
#  u'GAMlK2BF5z3H3wUsUJ_hkg',
#  u'LLDGTT7FExklkQvHebEjRg',
#  u'AeKTQBtPRDHLAFL9bzbUnA',
#  u'fSs0EdKmLJ7VULejtsi9CQ',
#  u'sG-fXLyIrR2fBIObuBrkrg',
#  u'qKZzLdcMouXji7YASALbBw',
#  u'Xh2LOgZKN5T_JjQjrTueKw',
#  u'64T6cR15UY0I_b9ayMiNRg',
#  u'vbuePEUjg869T_HWyz0qCw',
#  u'_45p8kOA__aNycVVe-n-KA',
#  u'sKakNuBkT4-Jc7ugp9GGew',
#  u'QucBkYI47PfGyPdWu30cIg',
#  u'T_gR7-Ojp7k-J5PpUfd2wg',
#  u'4uGHPY-OpJN08CabtTAvNg',
#  u'7hZGtb0Gd3aRcG1VH-Udcw',
#  u'ZR87Qw2sB-ljFWClGk6X0A',
#  u'WW2usZ_qGahfXGA5rhKvZw',
#  u'WOAPt0iUPJ9Tdsv5h-Z1gA',
#  u'PwpfzdITG3-D5G1LBCwHsg',
#  u'yhrTMjhnrCsqDR_tJfyLCQ',
#  u'yIXOZJQXHAw3Zp9mVqcPPQ',
#  u'7fuiTVuFt7CTAQRpFQf8DA',
#  u'ZV1uiya7_lBfoZoU-FJSMg',
#  u'G2AqHSVc8t6I21qiHeq7jA',
#  u'ff00hYO8rPFDOF8YKhLTdw',
#  u'94twCOpyD7FI3i95oiXnmQ',
#  u'pAWgUsCkPwJG4Vw75Wk0aw',
#  u'ZOa7CkROQBhLuATpNHcHgg',
#  u'Ew_BOifmNQrh4P1VJvK5qg',
#  u'UJDfIlh5DhrgZ33E5Qmssw',
#  u'ciEBHH91Hz4RciYUUkueNg',
#  u'JU-y40a_2XjhBe_G5jnSAg',
#  u'fIFe16c58gp6L1UAfLxGZA',
#  u'lbDBVMkpSKaVgEU9tJOq2A',
#  u'n95VKf2ldyq2DQZJJ22Dxg',
#  u'J1Oi8wybu3BYYc2-I2ynPg',
#  u'w4b7gW_l4uL1DdWwwPTucw',
#  u'QDLYkhj0yS47Qgziw1DDHA',
#  u'dfzu6qhwowIc0rFeD2HNvg',
#  u's3u1ET2VN9NkY0qsn9gSwQ',
#  u'qGffC4h6UOTSkLhzjj59FQ',
#  u'fphcaoXU9ywS5t3zEqYyvA',
#  u'MQqf0EPF7TOte49T2Op2Kw',
#  u'T4AyBSffvi3prLrw0H2enA',
#  u'qhHwbSltc8MSm64vj3wcgg',
#  u'lzoTXcynmfZ6Ler5B4HbfQ',
#  u'F706EOWbbOe_zdXrVc0jew',
#  u'2E3OHy9UBnj3hoVw9RKx-Q',
#  u'TS7WJefIj-Yzmjw0A81UWA',
#  u'f6hjKOSap9pFlNMYxGtjAw',
#  u'UjAj7SjUQg8znkwk_gaDJw',
#  u'pCobXgTy6DIfBaT4pjlq0w',
#  u'kInPSo8q0PgA-yp2nws0Uw',
#  u'3OPWaOkumRzSdWGsbMgrEA',
#  u'5geSNRVBlvhoJlRK1zAS0g',
#  u'Ok6n1zXuXVgrazcrmC_UKQ',
#  u'lZZu104aHbtrDJ17whp3wQ',
#  u'ud94l5Yt1bregMm170LE5w',
#  u'hKmjsDS-nK-cPyUyix-PiQ',
#  u'0JBktMcQgwxObtrwjILJuQ',
#  u'7VDrYNPhDKFURZbK4MRi8w',
#  u'ZWuO-YghNqtcAO7Ar-MFEg',
#  u'YSlm_JoOHciVmKNwBaVy7w',
#  u'hN0eltVGO44BocEknPliiA',
#  u'jTaaL9gLND-qdJurleTQ1w',
#  u'uqgNQGDC_AQY1f9M3tPsLQ',
#  u'828CmrhMEUwSzrvZAlJ_LA',
#  u'LuYZUc1MOG0pA146SCeXgA',
#  u'e0HQNVQcfsTavbOsIlCd6w',
#  u'kR92Dbu3jwrODAhATsZ_3g',
#  u'thSTca8QNPLejpSDoharcQ',
#  u'vp6YA3fFQWpQ5kqPddlQ4A',
#  u'vSAKKH1XIeKjo7R6tXt_5Q',
#  u'95sQlDylaJ21U6iEl_MEXQ',
#  u'22xuKtFKYUXhTbIjkxGFQw',
#  u'nBdUTu6WFZBaunP8OlvNMQ',
#  u'KxJLGqaf7JQKYQmWgXUU2g',
#  u'ivi5jHjmf2uV8faGJ9Rfig',
#  u'HPDhf68IVvvO7nX0iUVlxg',
#  u'WCorga9tk_SayxbZbP7Hvg',
#  u'75n7FVIObWM3iMf95duQOw',
#  u'0QI1fVQ3dYUws2DZhBGDpQ',
#  u'RzVwAdOxT9JQkeoeBMYPoQ',
#  u'U6zBp5ZyHWxbVnT5gpUxnw',
#  u'5lfBfk8OSiqUkxfufYTahA',
#  u'O09jXZxh7L2PMC12i6Mt4g',
#  u'-r5aq7vjN6lMFDZ4XYErkQ',
#  u'ZxmKA8b7njab1DNzCEU4Ow',
#  u'GWXU5xROhcnMIUaUFEtubA',
#  u'sJ9omljhmwCOtwYEQ-kbnA',
#  u'Ks-bqekP7c_lGN-RCBr79Q',
#  u'kziLxFWC71Z6PbKscj79HA',
#  u'QSrv56Eqa7xjCMtv5-BgBQ',
#  u'QrRNFiSXmCo4pzVLAhA_bw',
#  u'QwrWxzfGdv_bMiFrDaV4sA',
#  u'EolW2H_wkpYwWbBURN_4gQ',
#  u'qCOCPoxRo9_lLixup-TPTg',
#  u'whRXOWa9E58yMXi5v-AT3A',
#  u'9eYvD9isKnk1TvZ5LX5C1Q',
#  u'yBvj8B6e0Bj7TRM2743Afw',
#  u'M7AMdpRP1rOol5JMYeg3dg',
#  u'TWNjTof9SeYi3I-x53MpGg',
#  u'lECyW46mBLw_cyuP9yF8Hg',
#  u'VMKUtS9X-jtCkCyMsYuvMg',
#  u'6EJGBWDGwZb64x5z7XTxmA',
#  u'6Gy2p4w5Vo9ECuzappvd0Q',
#  u'ZQZzgR51Yf2PlDpQrwHkOw',
#  u'Ruyo0jO4ZnFo_-91CbWPPg',
#  u'kgt13cwkP03NS8FJKgdLMw',
#  u'nZgYNbl1XlZyyKlISMoG6w',
#  u'Lj_3EwHHkMsbQt1Sxa5Tdw',
#  u'VYCbveCk-j4UR_aSTuASJA',
#  u'HvGfGAi-Vdd3IkiD9CC0mQ',
#  u'kNGWOprBFnteCQUGpLnM8A',
#  u'1_tzgIokeCFWkeLpPzMFqw',
#  u'I0kZ5AgtltKOpZIY8jOJBQ',
#  u'5N_W39NYmIPO-Vo0DNVPRg',
#  u'I1wKHeee3qnA8Io5xGaLjQ',
#  u'PzQJMdqmvGftgFwitgU2oQ',
#  u'w8sRfLP8U7uX4OktcSbb_w',
#  u'OvE1oiSg9gaB9cLGzBPlnw',
#  u'231MA8w0WQUzxvQlOcnd8A',
#  u'QfSLGqyUS3J_kIsejayksg',
#  u'5OE8-LC2N0QhD_KqurPfzw',
#  u'Cvfi5N4zR9G05Pbg-Ud-KQ',
#  u'EcUM3ONkY1RUCB1R1_4FrA',
#  u'B3X4Cbty1G_m9abGL47sQw',
#  u'lnUXlYMh0UfrtVfnYo9mvw',
#  u'wZxrcIHmkhT4OHvIxPwd_A',
#  u'IUmAp5W5MaCvQ7I0NpF_fQ',
#  u'70RsWrhsmCleL4X0FiBQ5A',
#  u's_aCmrCP8QmOHASsOlA33A',
#  u'FcsjpyoUDp8oR0OblxG-cg',
#  u'lmYaUujbYrDbc_U3Jn1Ecw',
#  u'pF1NXrHOIhRTZOJhBC0WEA',
#  u'YwWRR64tgBgo2GZ2cqYmww',
#  u'OAyA2ogCSAn8UHcI9UuQ_w',
#  u'x4moNQwMi_-dZRP_a4-gag',
#  u'x4OswalQVHdmKbY9YiGz5Q',
#  u'Bp93pemXBdiEkZqdK-vtgw',
#  u'jHyatTHCKQXfuxEBP36-Uw',
#  u'mnNrwnFeO9Mdywxs2JY_Ug',
#  u'DW6SI2KxcfXBHeo9jEr4lQ',
#  u'Y3yvG4fGfOR0iJkGuM-NDQ',
#  u'itFwrNtjrQL5NPMYTeD44g',
#  u'g5jQgLcnB338vsGHyyL4WQ',
#  u'T1Ow8cCmbgSvKU9UP2zPLA',
#  u'uBcUz2Jnqu5OzXnuAWaJew',
#  u'qnJgp2Ezm2ipM6R_6Ubfaw',
#  u'_2FUpthYr7h9VLNbe9Gxyw',
#  u'Hb6n-TyLhEDdCyPyH3E3oQ',
#  u'NbqbD0vR84L3VN59J41ePg',
#  u'blBsSQPXO5T8bWr7-pu-vQ',
#  u'Xsp9Dy4PQgAssCVk2-f73w',
#  u'ZN1erjN3huMbkGAS0V0DOg',
#  u'Fr9OoqQplP76DsntQ-2ufg',
#  u'eZblSTFIjpqPtDawFi3UXQ',
#  u'5hSOoDzMy-N5mQ3l9AbKvw',
#  u'lytsOcdjCk9KTf20eHbBFQ',
#  u'Qs_rxSL6BfBFzAr30VLeuw',
#  u'UGlXDK8BKOZCroDTJ8nPKg',
#  u'wVQKpI1jCKgu6o4zADvIuw',
#  u'eHD1iu4B5yd_wj_uiSapzQ',
#  u'beLBiUPst9nClMbOQMIaQQ',
#  u'rYUSp2-7ErGJGi-MSh_H4g',
#  u'smHk8_5PELTQMY5FPMaCqw',
#  u'z3hkiTwFgHx6P8IGUABfuw',
#  u'GVLcTRS3DTMKWcorfDgw6Q',
#  u'0iZBk8n6Do6-488w9qCnYg',
#  u't6SuvEq9PPVGzNv5bJzDtw',
#  u'h7R_IMg3nss8I5nV7sbmfg',
#  u'AxScnvjfLqpPmTLXGjNhcA',
#  u'aVCIF4JaQO4qiRoiUWEt7Q',
#  u'ud8COzuslLF48ohHgAIECQ',
#  u'm4iGF1rnT-1njGJgq8JLMw',
#  u'n2hnpyj9aN942TnOkE-ZiA',
#  u'BSlmhfVEsy16C_ZUpcyB8w',
#  u'OS3VOCuv0SkuWyjsziwj1Q',
#  u'fCfHTImR20vtL1koU_H9eQ',
#  u'GoKArNsn4O4RQi3M2Choog',
#  u'FVR5EpCfQFCuT8L-77RZZQ',
#  u'FM3JgsDg5vLJ2x1_NM9CcA',
#  u'deFBCKjvB6i3-LX12JlIuQ',
#  u'GVbH-lCr1b122ouFueNihw',
#  u'reCYCgskR-ZAtUqRenu-Mg',
#  u'3ojGEFVvMY2WYk_xhmRjHw',
#  u'3Ull4jO_x_rAxUujkbiq4Q',
#  u'zFcd_gelAUEwAvJOgiZpvg',
#  u'hrOYw0Lx8CUSIFczJv7Fug',
#  u'NE4Q42OVJdlibncRXtJXvw',
#  u'uigVIpiLYQdM3mgCgioMVw',
#  u'2lF_8RZRBd9STfk_QwAtmg',
#  u'vDeUfhKqA3yAEARq_a6dPA',
#  u'KrpzkbFvCTcM7fPVZN7h1w',
#  u'GCty9fuEWrsl8o5xU7C38Q',
#  u'f9G8rYZ-HpQvekvizABeKg',
#  u'smoGuW2a2Nume83mB3JJSw',
#  u'cTz7lxA0AdWKMba6Bvsi3g',
#  u'7CVoKgPjQS9KknIsz3Bhcg',
#  u'CEaQ8qPKHrlUzBiZkIPdEg',
#  u'kSSvuD81S7T1Nrr2qsXVPQ',
#  u'3DHwRjWomOtnxM1v6-bPEQ',
#  u'F0cNqcDlAwB4qVsRuGbFnA',
#  u't1c-Ix7GDbkbcKy_ZO71vw',
#  u'6UGAtEw8TH6J6YeRRZpwKg',
#  u'wmNyt1NFgK_yhJndXmck-A',
#  u'j72BJLvldv1gw9mSpUhiDg',
#  u'4OQXZon69AkUF-aLXEGImA',
#  u'y_L32uJc_sPupdjhb2YO-g',
#  u'vyoJqpSIVSZgpGjCXgtL7Q',
#  u'NgtHeii61KsVwqNjXIwX-Q',
#  u'IyCwqORkMSmK4mAgAFHgnA',
#  u'yUUnMqu_qr9O4EuDCleKeg',
#  u'ECO2Bi8a8sPjW6f7JMbhdg',
#  u'dkjnemtqU_Zfhd9XnOkv3Q',
#  u'NJ4d8pv7wUwJ8IZfacRwmQ',
#  u'uft0J3Wd5JkDOcuqjoNghA',
#  u'McXavPYFZCsldUoXITNoGg',
#  u'05fTEsjUPVo5jks8PpNKCQ',
#  u'zN33MhQmlCB3yhlunL4M9Q',
#  u'9L8iNVpzkY1FiDgI4bqu2g',
#  u'VRYTY0V7WZcP-yzv7bkllg',
#  u'EemFk0x2E-vlPbnJDHfbxw',
#  u'bntRdC23ijuKo41SBrPgFQ',
#  u'J7UVAa5-5rhWI4SE3wEZ0w',
#  u'Ko08oUwSm8E8IxSrunx7rA',
#  u'bFXlrZNsDOEhSW-Qnkt3mQ',
#  u'LwTK65TMrmtjpdZRloQDwg',
#  u'LSymdduTtYl5BdIQ3kv_3A',
#  u'QnhfhHUeURnpWBoZ-cexTw',
#  u'AgtFQVxo-PGQVsOdY6Nvdg',
#  u'Bpp8unXZmbyxSZS7D93Jog',
#  u'QvXKpK2KsguA8j22Ak65dQ',
#  u'NPgEbfZ2kvbG7oTIuwkUYg',
#  u'wrlKQNus6TT80SWa_bVB5g',
#  u'ODlUjRZ4mgrN93YmZFKPFg',
#  u'kwEQ3uY9Jwmknb5kNg3UlA',
#  u'Clz5M4GWy4t45vgZhz3Y1A',
#  u'BvbFnrg21OU2dULq3OlqcQ',
#  u'5M2l0nRGEBKJkUGaZfR5YA',
#  u'MextiDUuM0RE5PJZzVFswA',
#  u'33aOj9haiHsULCUmFOZ7uQ',
#  u'nA1_v_UsZSTeKOwsMk7iSA',
#  u'pXTwSV_zMOJZ0S81XA-O7g',
#  u'15JT2xhzP_R96mT6rK882A',
#  u'qmIT3LC-kMNiOy7_XpWNUA',
#  u'VUk5T-D5EYoX4faKHrEo1w',
#  u'3eERfPI8Ak8383vb5x4Gow',
#  u'NI6HbJtkRSwzcaSxMaSSwg',
#  u'i9xmoc3CRotbK1OZKm0TnQ',
#  u'cHkHYcOw0rkyC3t9gXjeIw',
#  u'S9jqNbEHIsOf2JTJ-yIe0w',
#  u'j_pce4pG9krrBeYwUni8Pg',
#  u'gHZLdCEYDT_hHrKDgHP6kQ',
#  u'wL-h9AXEEMlc8A1Alo9vhg',
#  u'xIVf0oSwdhs8He4PokqlHQ',
#  u'e_eY2EmXhno4qwsZVkWq-Q',
#  u'pI70lagk6M2cHExvRGBEyg',
#  u'axGfIs1D9X487_-ZA_wcQw',
#  u'JAAjvGyYdAaBTf3z5KhrkA',
#  u'O2ZJBS7uqGA0kGDr3-VgGA',
#  u'DS2smdabGmgClXvlvYB9xg',
#  u'5vKdGeias7HTd3o6qojDFQ',
#  u'xNmU3k70I5Rpl9OnAre5gg',
#  u'F3C5bd3xh4UAN6RWSKItlQ',
#  u'_3fswReXCBK1Fidkll5Piw',
#  u'FQdQqgLGIvXb14HHKhureA',
#  u'98Cs_twO8VAroN3oA5TkGw',
#  u'owUZBugX032gYls-gkSwmA',
#  u'q4khSPgiGK9MoTu2NC2yTA',
#  u'MHUX3HRj-gtHlg-YTbIVzQ',
#  u'7Dznb4ZA6swheppiS9nPig',
#  u'bfcNEOEsC3wyrV_DRUO0xg',
#  u'vy930iKMNjeQqXE9z5C1gQ',
#  u'wdQ6nsRRb_LSON68PYhFOA',
#  u'-36CwMJZJigqPMYrx9BJzw',
#  u'bmphS_u3GKdDboTpN4zTww',
#  u'1T1hQpU4kbukSLoz947BWQ',
#  u'LbVBhtk7yMVgDAuoiknBFg',
#  u'NhS1rFM9j8cht9asgPOZDQ',
#  u'bGj9djLAHjNR55OXsIDrAg',
#  u'V3ruBXjLGWniPNPQOzRhiw',
#  u'hxU6xPTrOz2qKAsRz58hEA',
#  u'D54vs93Q3NZkh5P99V2n6A',
#  u'hSMxX6NtB9MgqqamnLtrfA',
#  u'xxOQ7h6s3InV8o8DOVHlMA',
#  u'8YUBxK42BUi7EMn15UxoJg',
#  u'-CAxtEWbiPIJlpbWq4qz2A',
#  u'boxOMuEguLds_KImannFAw',
#  u'shKCOCGEQctC7N4AvP3nWw',
#  u'6D24UL_dB6CKLvqwkA4-Yg',
#  u'rKD-phI46Uc-sQ14lv258w',
#  u'jRm3L5uMHBhG-tdtsvfyUA',
#  u'5HB8ENzXYe0dl7O_YNHXAg',
#  u'8TbIx8H3FufrHlYZH4IcWg',
#  u'0lWQSXID3T7K3DbjX7CpqQ',
#  u'CBumPtpjISns8paiSwtlLw',
#  u'-LL8qFtRQv3JY-48gs1xlw',
#  u'rwgU2XEFJ7nyCHvUnEC5ww',
#  u'3o6Jr6gjh_IulczcWdt_Aw',
#  u'7XcrywweW93zN2YH1dTADA',
#  u'VRtVE5VHgVUISPxV3jY_CQ',
#  u'PIJBdYPg4E42JdDkTjXkPg',
#  u'44LXMxCJo1tqmCpVq_cwbQ',
#  u'sv7c0OsCUXT9-QNlCghT6A',
#  u'RCAiM58UdsGl94QA7HeCAQ',
#  u'xNyTjXh2FRuT4Z8Ncj9WhA',
#  u'DWxHaMN_6yJskjxK_rt_gQ',
#  u'BVCDPqlHMDPLWn9EhdDXNg',
#  u'6HCFfg-1HKy6G5t4b_hUPg',
#  u'4eqw9xCbCmNQPV-AQJcXPg',
#  u'0sGv8StC2mq49VeqevMiQQ',
#  u'ZNdsRbGeOfrYYPRl6AziCQ',
#  u'dQlvrZUS-BOxs9KperQbCg',
#  u'uy9IblmbJogF1TEUc6JHzw',
#  u'_MkEsZayoYMMOXE_qCJYgA',
#  u'na2KwlzXBYxzKWTxBRNCNw',
#  u'wB1GOrySpkix4Phmt5lObA',
#  u'8x__4Jd-JMoWUYCkv6IJwA',
#  u'YJmHANxQvmldWbxqzwdaQw',
#  u'qlbwd2A2E6PMpL2sK2TxAA',
#  u'nVPe8vSrvGStsupNliN9nA',
#  u'WzjRM6h6dZFBwr1rvwjvPQ',
#  u'oCG5dfkjD45txG8hoGPPsQ',
#  u'aSZzH68--YxNQYAO5nKBkA',
#  u'F14WDg0i6yZwXbflJ8ndaw',
#  u'j8qsf2QbpgkUwTe3RORLBw',
#  u'95zGhhpLipJ-XgUQUoIpNg',
#  u'pULc8-D98CrVhLciNJzJEQ',
#  u'HpaYCM_NCauI72LLXxC6SA',
#  u'3ax5VsgwzNRAjrWcozCPBw',
#  u'gJCZt9_A3n1YDirxl0N9Xg',
#  u'A8q8miBWQ5-wgLwuE1L-2Q',
#  u'_OQ9qkPuDmJQq63qRUzY2g',
#  u'S9vMfHWXGviNQMZOEZYGhw',
#  u'aiUid8bYNV8XDiSk7EKOIw',
#  u'WZHIYPqGPaPQW97GNrkqjQ',
#  u'FmsSGHdahYI6VarnoQhGcA',
#  u'UpkfQApZT5rctZicZ_ZTgw',
#  u'EIshA1evDfCTcuI0dYUo7A',
#  u'bZReunQUclSYApawpe787g',
#  u'm7FpRPI-vvVzFVi2CfHFzg',
#  u'0IV5L36XeQShzWiUhom9bQ',
#  u'8-HkVgPClpSli0ug3Uk-sQ',
#  u'_50NM_YcjphNZnkc9UiKOA',
#  u'29ZKSrOXaZ9VydCqRw1GLQ',
#  u'eLPld7Q17XxlclFGzZQX5g',
#  u'iLubiQC-OqI2WCg0-xs1rQ',
#  u'OHsuvX4rmhnPvvRBb-QK7A',
#  u'wRnX8AV5CAAJnEgReTMaHw',
#  u'5m2HPI3fp6Eq565mlquL0w',
#  u'I_h0uin_oo0WNqFy3qKEpw',
#  u'OoflKXY2YUso9tlSjHKiqg',
#  u'H8MNEORY5wNTC1lQ-p9BuQ',
#  u'qth1W742hXtFoNVYvuHBEg',
#  u'k8ka4-hVR-uxNlCvDt5Vaw',
#  u'uLJirdITHvQLKWIW6kKoWw',
#  u'pw7Ri54ONnKzSr3p3h1lMA',
#  u'CJEM4qlKqLJ7EO8rtuFRpw',
#  u'um-aCTdkduQz0-pJF6q59g',
#  u'CF3dd_PNGAjK_Lo0eETTUA',
#  u'fJJw8Bvw5QP4j0GqE94OJw',
#  u'P0Bf-1S_A_g7IbdGuAnG1Q',
#  u'3MmHmJXr8Ltk_Z5EGE4KUw',
#  u'_tS0YfyPDxOXxrN4Kl2_HQ',
#  u'sJg0ELnsDeuFUJcVubF98g',
#  u'NmzDkoKN_ERF6CDVBYp19g',
#  u'NomKkbod3jnl7_aiPgeL-w',
#  u'nEY3mwbpAJlQ5FOQ-F4Giw',
#  u'IblEAPlN6dfkJb1pvgRrJg',
#  u'7V8ESs-p-aJ9KhPFEbQjLA',
#  u'gu5Yj92bnXnxNyMdxO14VA',
#  u'e5uRGtS3HNsBayKVy3U05w',
#  u'5YgXxBUzhf3qh8F8wYSqsA',
#  u'od3Ux9AdGbDHMrj2X7Xt0A',
#  u'm9xE2lgdgtfV-yrpuGQy5g',
#  u'wH8J9TI8ReocYZ3N2W04bw',
#  u'1GYjuEYlbaQzEaCBKGirJg',
#  u'1syMfUAu8so1wjntLW8Y8Q',
#  u'uHPXU5sWTZRILmMQbfWcJw',
#  u'i9mKoASjely9zlxSRYfCJA',
#  u'41Lse9Lm8l2ai-txhbQIGQ',
#  u'vvUqrP6K5ANqXEfY2JfnjQ',
#  u'lfmvmL6iHq9-IDABLeNsuw',
#  u'r4VFTmgE_h6n3JnjG-Q-KQ',
#  u'M_AvyTDpBCp2f-ON_20JaQ',
#  u'iupX3nvMJMiV07M3VKVl4Q',
#  u'E9ZsPtGovfEPHlMHkDdlQA',
#  u'9SrR4mkEsyimsimrc-vP4w',
#  u'g_qX41w9wXNd0ZtO97f7Nw',
#  u'_GWuXjPNBnO56OaT_daPZQ',
#  u'ejS_lQteyzG6PR4gxZN-FQ',
#  u'RkZIVN-Wyii8he3oO7GdgQ',
#  u'cmhI53vn0vg_OvzHRP87Iw',
#  u'yxxLFua918P53BQADGCSCw',
#  u'y-mae7E1GabtYgVwhiWnXQ',
#  u'DCEYP_kyCyircsq4nTWJdg',
#  u'HbLdXagXSfdY6KhVOWqaAQ',
#  u'dwaNheCWKYvw5QMrd96vUw',
#  u'rad3s5u3uNco7mZXQ-arOg',
#  u'LTMEAdWM4m5tIDCSrkALIg',
#  u'ix8XGuorN_sKU0zJD4teOg',
#  u'vJcjhJ9rQP4-T3K_hdAjfg',
#  u'QJlab4DqvBRJPUfg7Vn5ZQ',
#  u'-GZsHVDlI6wvLsgD1Yaj0g',
#  u'oR8DWu4orNyi1NGbWig-cA',
#  u'ZA7GsC5JNswGGXSjsGwUug',
#  u'ubwHoadNnVfMB9dFV2uyTQ',
#  u'pPoBiFyTjwPSg3R2Q3AeVQ',
#  u'kCUFwG0CKp_W8pcwNo1-5Q',
#  u'cRfn_vMQ9YExuKb378CwjQ',
#  u'l593y9KEguq1JWVFcaL1DQ',
#  u'ZCkh7L0HyZ8L9RclT7A_cw',
#  u'6P3SsceAMT39CBlo0upqHQ',
#  u'hs6jwjH5ieps83Hhtc5oRA',
#  u'X4B9b-0zEClDIiN0AyCdcQ',
#  u'qrgod2lrYnxHwNWC_YYTyQ',
#  u'UQouZ1z2P3lvG9IZMxubpA',
#  u'Kxp8cIMt3-vxwtCSsL9QKQ',
#  u'IUNrEkrbBTd2xbEHC4mutQ',
#  u'tJhh6NDsNIwWMpxlP-0F7g',
#  u'N8uXuqa_Pee3PuUD_oU8EQ',
#  u'1pIbXL3IyXFmKqQFv-g-dA',
#  u'NNGAotTDCNT0qkltmNii8w',
#  u'2jh1-DuB1L5t8pd1vXutgw',
#  u'gq4pttYxP48kC6Vm4yuzZA',
#  u'R3FLaYuHfSXnwA3s_PXw6Q',
#  u'-tsCj7HZ1TT548bcz8U3ZQ',
#  u'em3gydy9BgDBzMTmhKpt5A',
#  u'QXTN5WwZxvf-Z940RmDUdQ',
#  u'n4gpqlNezLD6zJ9HrD9XjA',
#  u'eCuQ6JHogw4oOfgOG7nPgA',
#  u'9hP6hRDuX1QVWZEjUTVo_A',
#  u'OQEhO5aXQJe1KpiuVPG7qg',
#  u'TN3FpaIIX9j8EOydMvYOvw',
#  u'naLrErBuJr9IWd6_rv6-XQ',
#  u'dguJwaqGwa3SSiogFuZrqQ',
#  u'8S31wjHVC1Rx71ooEcTRTQ',
#  u'LTHq7A5vVAwtqqu5i2ZLUQ',
#  u'cJbaH81HP6r0eHDy8_738Q',
#  u'9gOBcfarkqeoCl1OBjMpZQ',
#  u'OrroVLyLtuKJGA3RJoLesw',
#  u'oerixQiFOO0rzaPkjkDNTA',
#  u'1xZbo0U7inuNHjx1bElwdg',
#  u'_fn0UIgqzCtxXcmHRi8FOw',
#  u'pf2c736iwGayJJpPp9I-hw',
#  u'iW4T61MZ_YPe3bLUjLEHbQ',
#  u'Z1FwK37rWbmLvZChmy-y2w',
#  u'enJGNU-A2br9d7sKe82saQ',
#  u'ZEOiwWUDKL_4ZZz2TWiUUg',
#  u'rpjwmrKICOA6BCdZfK7p-w',
#  u'hHneutBDgSpp7l9CUROyaA',
#  u'HudJ7VDcaxrdPbrWU67eJg',
#  u'3BBqVbU_Z-kCcUfV3xIUYQ',
#  u'9MOlB5i-w7Tcq4STHTuw9w',
#  u'cC08otMSMx_S4eUbmElKew',
#  u'OQRvWqRMNPfowfcE9cXrcA',
#  u'XgfKcL7eBJE9B66qoaIlJQ',
#  u'k2IvgjxKLpj_3iw2NVfe9Q',
#  u'4UskRuHsAnhF2Gzf0L1zpw',
#  u'j3xNAQtY6nFLeE6p4TpJoQ',
#  u'RFbAMMYjTN8uRKFPfrL-Aw',
#  u'2e2e7WgqU1BnpxmQL5jbfw',
#  u'hsM6PF4Of6RMNcQV_c-FVQ',
#  u'XziiAJUc8cgj3McljtnYVw',
#  u'K8dQr_82-DMpDudEv8PDmw',
#  u'Cm8adqSt3IZSmVLJRbNfyA',
#  u'7uLYslzc0NNy0126O60__g',
#  u'h-XjRidGcOuQ5erP4V166g',
#  u'H2dKOR0fzYiv7ebVk3ELzw',
#  u'Me4q6iXSjJyFsfKx-l3kcw',
#  u'CPTiooPIwzbM-WJc1Rsytg',
#  u'nF_mARnVRFQpS3boDNgy_w',
#  u'W-UBevF6tFgX4WiA8PvdPA',
#  u'U87W6T9vjwWnp28Zjnn4pQ',
#  u'8sV6eqDo5X8KgRjkEBpVzA',
#  u'jiS9KmggI7h64pKr1lRlXQ',
#  u'lwTsLqmIhRe1r2N6PqcgpA',
#  u'N0sUdCBcA3ScYULAkGOqxA',
#  u'5PSjlaVzR1RooMhYmjRmBQ',
#  u'PBkdlqw53cc2AZsfFD8AEQ',
#  u'3_H-sx_fq0hJJ8S2W02frA',
#  u'8l09P4s8VARDulVNRsMcmg',
#  u'S3iZm7-MKPhvXWZRPqC_Og',
#  u'PfXzO0BdNAoKjWKQ_bG06A',
#  u'msn1dd2YDQgBWrlx_hQYgA',
#  u'APe_0I6DqbNQonSlEkMSEQ',
#  u'LxxmtHFNZ5S-MyhykoE4Sg',
#  u'cvJDHk1ho0DxaF26etcr8Q',
#  u'WnBSlcek6ACsjE0UDJ1l2A',
#  u'6jdKnIjJ9n5knZoSj7qtDw',
#  u'DjOxXobyGDwWt89q4z1twg',
#  u'6dIZ2hjHfjV2ZaxS2H-fcw',
#  u'SWSZdo4sBhrcQSmN5e1myg',
#  u'wqOSESjr7ioLSAUOzzhqoQ',
#  u'0IJWOuv6BT3HYo2V-SttcA',
#  u'KnT4mJRLvi_57lsWtflWmw',
#  u'uNlyL9PbetafZaeIewUhuQ',
#  u'XI0imFHuxWf1kLThmR4WEA',
#  u'ymBSur-7YgjpcEsNSY682Q',
#  u'PSSb7S4t8j4W3RtjY-9fiQ',
#  u'Zlv0RZR5cFS5NzeXteuUjg',
#  u'e9TeHrdVJe-NaAaEXWapfQ',
#  u'H3SaoIWnlG-HvGQ8v6J6yg',
#  u'5PPZZq8-A96Fm3rZvP6fcQ',
#  u'92Z2b94IO-ovEUmrkzarMQ',
#  u'GJp4zTQPPsCEkUitopGfAQ',
#  u'YJwtYZ17Dm11H0y9VoudHA',
#  u'EV3MIitjwtWdgeHq3lr0hQ',
#  u'aX3dNl6iDh4FaSw7-ipvQw',
#  u'Jg5Dw1uQSy_emuQydIkjIw',
#  u'CNdV0G_B5bKSpDrQa55rhA',
#  u'994TtJYxB68eSscnCr94qQ',
#  u'lMhA27o63QiZIt-G7cXvOA',
#  u'PN9w-QGQtSwCmf4jcrme_g',
#  u'sBAueq0jUmlIH6vdgyP2aQ',
#  u'6ponQsJFfwrOZvV1Ns38-Q',
#  u'-NvziNlXkm-WNK4TtTs46w',
#  u'iM27P2Dk1tVocQ9ai1FHMQ',
#  u'JQpmsTVp3OSfFT6CubgxCQ',
#  u'DUDX6e_9RPEdyvyJ88w4sA',
#  u'tJvUgjY7dJhCunOC10tKpg',
#  u'eD2np2oaT6GOoa4H2FUiaQ',
#  u'0TdIt2d4hO46P_7E4wju-A',
#  u'r70nuDpkR5-g1oShW2ANvA',
#  u'7kSj36mgMGaqAlRJcjexFg',
#  u'HqX-wW-iRspulgRvE7eLiw',
#  u'JxhSLFM7l0l2FYZs1ezf4A',
#  u'PwTFdwexXt1ieYoMfN2j6g',
#  u'TRcQQJ6h4wdf2_zAyJXR_Q',
#  u'gvtwlFW29b92qcYUAH_v2w',
#  u'jEPe6jQ5K9zfnLudnnzO2Q',
#  u'slMC-vf5tw4v5sSMY-7a1Q',
#  u'nREHMbIzWdfWtOh4l1bT3g',
#  u'voPFKvVFm7b01xUyJixFYA',
#  u'bI9VF3W1SPQtsIRtfYZzWg',
#  u'n_d7HDsTdLc9IWwuPHBNlg',
#  u'I6DMTSrI2Vlp7Ai-Z9tUXw',
#  u'i6FHskgERAdKWjOXTjmQ6Q',
#  u'6bBJymP2jh-tenBY8zvL1A',
#  u'EgJaDh6PUnkQanbG7zjbLw',
#  u'84T2HrgUxW8hEBhZZhM3Rw',
#  u'HInwbp5-mlHseWLSyCAxKg',
#  u'H-n_ldCI3Q16rLVJsAxRMg',
#  u'agKdJFimKaicA205CoDYIQ',
#  u'qt1L3A6TpSw_36uFsugUew',
#  u'k-hE27MVMEBWdMsto1DeUA',
#  u'9jDEushRcdf5ZGoQLE-aIw',
#  u'5K7um3gd2nuJK7NhAieRFQ',
#  u'az3Im9mYzC1gq01y49Mbeg',
#  u'C185HewDKhT0s6JmFFFqcg',
#  u'qpo6O2Ozbrn8wFnoCM4slA',
#  u'Crd82TFkF-cF5WF_qKuJ4A',
#  u'wv-U4BHulKC0OxjkP5zPqw',
#  u'8zL3V6rmFKBess3bxPLAoQ',
#  u'ocZ11f_mu6QH2_cPW2Zfuw',
#  u'QcTj9AgGJA0ifMHCCPNblg',
#  u'UJ0ticTb3sDd27hN01QtFQ',
#  u'zMF2awzHDj3Q7CeH_Xojww',
#  u'g2ZRZXEKxj0SL86etbydcg',
#  u'wn2rSHNUDewPO7r5uWU4Yg',
#  u'O6MyV5uqwZabD5dKbT294Q',
#  u'f2Iga3A59AFYwoeAvc3e6A',
#  u'h0Bgl8mTLQCWakpjCRH1fA',
#  u'B7crMY7g2Haz8cvox8732g',
#  u'OwBPjUz2o0J5K3DzcHkBtg',
#  u'N8NiWbLzee9EOeMnz2MOlw',
#  u'UFyNuxNcuoJ6peYZANEh5w',
#  u'Muq939TfNZheQx6SI1pe0Q',
#  u'SkxqO4FgEJebz7kCzjvYYQ',
#  u'7yreItfpau1BYXcZaiq7KQ',
#  u'GNKYSfEwRL7enQYBKeA76Q',
#  u'NxA9bmbZkY46NDgQu1Gzzw',
#  u'bvPrzKDAvEed4tA2bNCsyQ',
#  u'LXrq0Fw6MCz70KMA928ldQ',
#  u'IALApn21BROm-knJfH96eA',
#  u'WlOCinE4LBkXgAIvP-D55A',
#  u'1a1WNQw-0lwjl2FBapFbHA',
#  u'mRSPWLcmFH8pf4_sy_znRA',
#  u'WjroQezRhqoKmflC9080ew',
#  u'dM0HMUpW89okNt3MgGJ-lw',
#  u'5cybURsCTS0zHH5Qbu0sDQ',
#  u'J6rIkpGl2ZipFDd5zk4Nzw',
#  u'96rDpZ2OBW293QNWPIPV7g',
#  u'pNqHRWlrbh71zbPZNd7_2g',
#  u'UEyXv6C3CyxVYmxRDWYgUQ',
#  u'-1B-DEGkLE1kDj5ENAF2NQ',
#  u'H2pm7yVZci7M5RKhAOYzuA',
#  u'f3ZhH3kIKvUdoDJhcRyZ5g',
#  u'VWhRZy_PFKYNU8qFxMvSRw',
#  u'WM46tJ53UYbpOz4hauboMg',
#  u'UFf1nfDi1p_301ty6u9IFA',
#  u'AmFV6GidAE0QfYUx6th4sw',
#  u'OL6SSsa9D7Z4IQIPJ_EGJA',
#  u'-DuZnO0oM7uKrRrWX1P60w',
#  u'AAc0nGWLioYSsAyfseMzQg',
#  u'xNcqwYAUeVOhe3KNC4Xjaw',
#  u'bNOx8Q50Q6bLxjSBmQDpwg',
#  u'bE_F716QBj0xdMGShapUOQ',
#  u'8T4aPvtpugzUxJc-DVrLHg',
#  u'0H7ewZ656xM0bulSMowWtQ',
#  u'NdQMBelvH0TTe1pIrnFYmA',
#  u'vGm5HVOg8M-I7lzAFLzrcg',
#  u'MI0OfnmlfkUh2xPhT1lQSg',
#  u'WcawfXDP0k8UfLyEoz_cvg',
#  u'_cCISzta6UPejpJku6sB-A',
#  u'W4CviqoXycVRO5n0F0QCRw',
#  u'b6qYCOz0vzJW4U81XLY8IA',
#  u'nzQJqTrcazg23EjdaHgqDg',
#  u'9KkLGqb-D-cysttQzIl6ww',
#  u'a0UCgr9M4HpZX9iIl39elA',
#  u'JZIrpctrRbJwmQvCPaThtQ',
#  u'DTaaI8_d5bcFBWbiisls4w',
#  u'lG0_hIkfBozThlcEOL0dZA',
#  u'EcVXqM7yZZeOO6jrLR-_xA',
#  u'au4X4psU-hsWqpz8UR6Kyg',
#  u'5YJTg4792Pf0QcpSbnu9dw',
#  u'ILoDsxtqtLU2oTMaf_laGQ',
#  u'S1S7_p2u8cpMd0-ZAsjahA',
#  u'DoDRDIA9FvRJ9Ujj1NpOwA',
#  u'zTVjTJYlRW8-cT5IQZpkBg',
#  u'BpR_oUAmIh6Q7Y_Y0Q_WmQ',
#  u'GfuApsBX3jHdZGgWi8PTag',
#  u'qeP2nIq3TCmhWFaFvaPtWA',
#  u'EQxbEKkHxNvRT_-S5A-Gcw',
#  u'LDvfJ8qo2njU9KY5gNMpyQ',
#  u'KcWUgvyl64Vp0PfwQRZQkw',
#  u'RkpXN1eK4hGBFjvTM1uK2w',
#  u'wxtqWVGlDW4JFDOAKofIog',
#  u'WvcDPv5Kk2xAKhmUoFx7TA',
#  u'9avj6sGmkoI3BPhdjNrT2g',
#  u'FdFyXE6qgDSNGyfVzTsJmA',
#  u'YZZ25gyX-E7yGVnA97I_sg',
#  u'bH6UxhVuIeQ72mBGtPV9dQ',
#  u'ofhhRbEYZnmd2eKsD575nQ',
#  u'xheJf3qJLLf4-Ck8ay3GFg',
#  u'dMjNtVrynJtz0MQZkGKcdg',
#  u'yP23rR1T5Q3Z33mol141eg',
#  u'PSg-nm2d7WLP3Jw2k75KFA',
#  u'zizuoDgDkNCtBzCj8T-Jbg',
#  u'pEYJpTbqCQLtSH_l91GbMg',
#  u'qpptyM9Dfns3AW5E_lsu6Q',
#  u'fQ7SbA43Tyv6Iqh8GbyqxA',
#  u'0GCpesRgXSVluFoB2otXlA',
#  u'3T-kSwIj0e6uRAArp8khxg',
#  u'0x4NXJFSQRRUNONxINTjWQ',
#  u'-uC5hF_5c-bCP5vcNOxNOw',
#  u'F1Pyhz7l1qNfvfje4gw1Zw',
#  u'V971TUTl5o1cxTsIhV7h6Q',
#  u'ISE4i1IoexdsByQMzropAw',
#  u'ubCl4IdtT8hfQbctB4lNbA',
#  u'jUqEkkM233NIJuYHRtfPSg',
#  u'u0Z0OwRYbwknE5Pr_CJhnw',
#  u'vhjdXf1dpYpV_unDVMFuEg',
#  u'bCRrLdBLel3y73tA8w6C3Q',
#  u'vejqhkjMGrHewvniyk6_9g',
#  u'T2NesLFF9Xhlho3iw8i53g',
#  u'P87XysABEal09pe9oFcP8w',
#  u'wLK4Ifw0XGlaeOD125PrEQ',
#  u'wd3nrdoEpikmGcf4NX0ziA',
#  u'MCS_VDkcxPRWcZ7kl_c39Q',
#  u'wvAltxmc-qhw-oQtmyXRiw',
#  u'1u0JcvPFQz9TIYrT1GnEhw',
#  u'Fw95xLMdwO9LoOtbBThr9w',
#  u'r_nzxK8pAOOpEM-tRPHXKQ',
#  u'5h3pG3cq0eNNErp27V6zRg',
#  u'BgrYM_W9X_5_fp7ek8zzwQ',
#  u'qii0hSxaINGRDkqniU-7vg',
#  u'nnPrX9mNtV5jKpo2cMjPWQ',
#  u'Xng5BfST9E30gMgPZ-q3nw',
#  u'9qDxlEmzsp_-_PTwBu6maw',
#  u'en2O4AiS0NDZ1AHgzYKzBA',
#  u'SfrHdU4NCkYWvERnWaOUqQ',
#  u'VgLiSW1iGkpzIEXOgvUBEw',
#  u'3OadREi9_BfBz5EmwoqQcw',
#  u'fwcoLKfZYMH6nZbAaeD6sw',
#  u'dRas-lkshHzfN3kY8chwcA',
#  u'JSuzEURjXIr0G8WrECZIoA',
#  u'5CGT-eGqL2zECmQpM9wPbw',
#  u'UJa2SxYxqPRnXQS_pkTuHA',
#  u'RBoU_WZIPnZBNlbb2DHzHA',
#  u'Shy4HqmyEewCLvq7Ub3Whg',
#  u'L_QPlfl-6DnBbYcxfdq4TQ',
#  u'dAMoHX6zBR4uvwKx6SetmQ',
#  u'XWgsRwCgUfd5xDdNwGyMTA',
#  u'HI7S-f1gJVcGYG38_JY5OQ',
#  u'WfdHpV_TeaftuwIGcwBQBQ',
#  u'rBPQuQgTcMtUq5-RYhY2uQ',
#  u'u5ea3QjzrkoIw_LoDefQqw',
#  u'aBznlTI64YiSavS8Vko63Q',
#  u'45dBeYgn3Wlqnc4W0HxDPA',
#  u'Atp1VH9m4_BizRyFluM-oA',
#  u'AarlEEwzIeyOgPOff2cnxQ',
#  u'dVAurLD1bBIi9IvuMFoL5g',
#  u'NxsCqQCpofRx08m535JYIA',
#  u'Ldx4Qe_R7w3OlSx3E-z0aA',
#  u'YyDc2MlVjuSHI8W85MTN5w',
#  u'5nCo6iU2uysEthHY5m72Jw',
#  u'bB1bVvOMkfvWFVbNmRl_VA',
#  u'uyEUL3Oskfa1fOYCksyM8A',
#  u'1zgwmE26LtJH5C1mD6MQpw',
#  u'io-DMLbRaUEdjqXmKjXsQw',
#  u'hU1wB9jePbd0dhTBcrpYvQ',
#  u'PQw4mxim4ytg8DpncWSm7g',
#  u'1PSXa1NyhW21P-iTgEs1uw',
#  u'bOvxdXGgqaJSzaOoh-VZLQ',
#  u'1hS8zXsdHse71i-LwJb8gw',
#  u'-qTomwT3ZKHapYevdnWUmw',
#  u'sFHj_WK6rzEeGcJxtvxrRQ',
#  u'UtEjf0xNOJoqyQst6EYUHA',
#  u'whJLVLRto7nVjmwk_XBV3g',
#  u'WsqAILgPniet5urqPFHocw',
#  u'jHLQJg-v7YXiXT11OQSqCg',
#  u'FqhEd4vV6Hg-0J49hBShUQ',
#  u'UW2gLVwL3qbh9ucnb0JjyQ',
#  u'1ZyWPSnj0wZmZ8SogGrWMA',
#  u'Tm4i61_FcxVAVoQjZb_6fQ',
#  u'ZiAmyZ0Mt5y781oYE7PjyA',
#  u'F15X6NKQiNuFcd5TeFgygg',
#  u'ibJxthQO5KcVFGAjXkKr_g',
#  u'bKP_m6qr3fs2UfKX_COeeQ',
#  u'XZWry6opFKs-BIwfpa_RWg',
#  u'qy40Nr-xCumWo1r7SNhbYw',
#  u'h9RR2Gu6hoGPiW4afh7zhQ',
#  u'XYiT9CI5hQsIR-ALddx_dg',
#  u'Hlh5x-cV51O5B0JIL_vZXA',
#  u'7y9h5HLuG7OomAipoKGC-w',
#  u'SfBHIShLosHKWWLFuDFUhQ',
#  u'dbjXu4l-KKV3bhMTvzwi-Q',
#  u'RRsm7G7Ke13GqnMFppcI6A',
#  u'0jLy2J-6omAKhBDzrNHj9g',
#  u'Xro3j2fouA42Stc540ZDvw',
#  u'7lqiw7SvtscC2U0ImPqDIg',
#  u'YLLgpK6W2JSO4QLT-LM2Fw',
#  u'Snvt71a7KDWYxeltag2zLA',
#  u'dKsJfvaTEGhXpJo3KRtx9w',
#  u'cCnQXsHjzKVULUYdG21_yQ',
#  u'1bJjWGYip-V2PGj4VIwbiQ',
#  u'G_bvx3BjuoWr9A_zfdZ6IQ',
#  u'3ovqR1z7Imm7uY41m8_iIQ',
#  u'pZjUk1jHZNaoO6cso8OGcQ',
#  u'xj8qUeH_SEUgieSTSwXMvA',
#  u'ieODJuvwd-Tccs-cCtCENA',
#  u'mBEBwu-SIaB8YvUawhBUCA',
#  u'I5Tk6rxaAX_cWHB_yi1qDg',
#  u'TSSNmAcPraYae5yprqaEnQ',
#  u'_xmJB767rROtAy6XepMlkQ',
#  u'1LVq-vrSkNSD0EIIBLnlSw',
#  u'U4LQUO2VYiittefTYBd4oQ',
#  u'c9hEAs-OUdjISt50kyc8rg',
#  u'wdqucaPeyerBpRyaEpw6Yg',
#  u'G9MgEsEN9nWNpAOnek216w',
#  u'fkq4beDJ0OOPDgeuaOpzrw',
#  u'GPAXhDmvWwp2g7fOutoDQQ',
#  u'sAbRiVqmxNdjTja_vmnsnA',
#  u'T7oEu7M8SENdblqT31GjpA',
#  u'H7EdgWJrR_nBJGRDWP2FGA',
#  u'l_qgSgZfarlgVjYy6NybPw',
#  u'BsPVtrxmqHeZ7BwORWLvrA',
#  u'jltLP6_SrYYkynpSuxVlwg',
#  u'WWLSUH4M4DYw86mhvCKyeA',
#  u'PdZj1gylTC5AaTO21eOYcA',
#  u'wmr3ROnBokPZXKZGLGLp8A',
#  ...]

# %%
np.save("temp/lasvegas_id",restaurant_reviews_lasvegas.keys())

# %%
len(restaurant_reviews_lasvegas)
# Out:
# 3822

# %%
from pattern.en import parse
from pattern.en import pprint
from pattern.vector import stem, PORTER, LEMMA
punctuation = list('.,;:!?()[]{}`''\"@#$^&*+-|=~_')
from sklearn.feature_extraction import text 
stopwords=text.ENGLISH_STOP_WORDS
import re
regex1=re.compile(r"\.{2,}")
regex2=re.compile(r"\-{2,}")
def get_parts(thetext,seperate_w_adj):
    import itertools
    thetext=re.sub(regex1, ' ', thetext)
    thetext=re.sub(regex2, ' ', thetext)
    nouns=[]
    descriptives=[]
    for i,sentence in enumerate(parse(thetext, tokenize=True, lemmata=True).split()):
        nouns.append([])
        descriptives.append([])
        for token in sentence:
            #print token
            if len(token[4]) >0:
                if token[1] in ['JJ', 'JJR', 'JJS']:
                    if token[4] in stopwords or token[4][0] in punctuation or token[4][-1] in punctuation or len(token[4])==1:
                        continue
                    descriptives[i].append(token[4])
                elif token[1] in ['NN', 'NNS']:
                    if token[4] in stopwords or token[4][0] in punctuation or token[4][-1] in punctuation or len(token[4])==1:
                        continue
                    nouns[i].append(token[4])
    out=zip(nouns, descriptives)
    nouns2=[]
    descriptives2=[]
    for n,d in out:
        if len(n)!=0 and len(d)!=0:
            nouns2.append(n)
            descriptives2.append(d)
    if seperate_w_adj:
        return list(itertools.chain.from_iterable(nouns2)), list(itertools.chain.from_iterable(descriptives2))
    else:
        return list(itertools.chain.from_iterable(nouns2+descriptives2))

# %%
# %%time
lasvegas_reviews_wandaj = {}
it = 0
for k in restaurant_reviews_lasvegas.keys():
    if it % 50 == 0:
        print it
    lasvegas_reviews_wandaj[k] = [get_parts(restaurant_reviews_lasvegas[k][0],True)]
    it+=1
# Out:
# 0
# 50
# 100
# 150
# 200
# 250
# 300
# 350
# 400
# 450
# 500
# 550
# 600
# 650
# 700
# 750
# 800
# 850
# 900
# 950
# 1000
# 1050
# 1100
# 1150
# 1200
# 1250
# 1300
# 1350
# 1400
# 1450
# 1500
# 1550
# 1600
# 1650
# 1700
# 1750
# 1800
# 1850
# 1900
# 1950
# 2000
# 2050
# 2100
# 2150
# 2200
# 2250
# 2300
# 2350
# 2400
# 2450
# 2500
# 2550
# 2600
# 2650
# 2700
# 2750
# 2800
# 2850
# 2900
# 2950
# 3000
# 3050
# 3100
# 3150
# 3200
# 3250
# 3300
# 3350
# 3400
# 3450
# 3500
# 3550
# 3600
# 3650
# 3700
# 3750
# 3800
# CPU times: user 1h 32min 50s, sys: 1min 6s, total: 1h 33min 57s
# Wall time: 1h 36min 5s

# %%
with open('temp/lasvegas_word_adjective.json', 'w') as fp:
    json.dump(lasvegas_reviews_wandaj, fp)

# %%
vocab = []
for i in lasvegas_reviews_wandaj.keys():
    vocab.extend(lasvegas_reviews_wandaj[i][0][0])

# %%
import collections
lv_vocab10 = []
d = collections.Counter(vocab)
for w in vocab:
    if d[w]>=10:
        lv_vocab10.append(w)

# %%
len(lv_vocab10)
# Out:
# 10364

# %%
lv_vocab10 = list(set(lv_vocab10))

# %%
reduced_lv = {}
it = 0
for (k,v) in lasvegas_reviews_wandaj.items():
    if it % 50 == 0:
        print it
    new = []
    for w in v[0][0]:
        if w in lv_vocab10:
            new.append(w)
    reduced_lv[k] = new
    it+=1
# Out:
# 0
# 50
# 100
# 150
# 200
# 250
# 300
# 350
# 400
# 450
# 500
# 550
# 600
# 650
# 700
# 750
# 800
# 850
# 900
# 950
# 1000
# 1050
# 1100
# 1150
# 1200
# 1250
# 1300
# 1350
# 1400
# 1450
# 1500
# 1550
# 1600
# 1650
# 1700
# 1750
# 1800
# 1850
# 1900
# 1950
# 2000
# 2050
# 2100
# 2150
# 2200
# 2250
# 2300
# 2350
# 2400
# 2450
# 2500
# 2550
# 2600
# 2650
# 2700
# 2750
# 2800
# 2850
# 2900
# 2950
# 3000
# 3050
# 3100
# 3150
# 3200
# 3250
# 3300
# 3350
# 3400
# 3450
# 3500
# 3550
# 3600
# 3650
# 3700
# 3750
# 3800

# %% [markdown]
# We then create dictionaries that index words and businesses:

# %%
lv_word_to_index  = dict(zip(lv_vocab10,range(len(lv_vocab10))))
lv_index_to_word = dict(zip(range(len(lv_vocab10)),lv_vocab10))
lv_bid_to_index = dict(zip(reduced_lv.keys(),range(len(reduced_lv.keys()))))
lv_index_to_bid = dict(zip(range(len(reduced_lv.keys())),reduced_lv.keys()))

# %% [markdown]
# We finally compute the document term matrix:

# %%
from scipy import sparse

nonzero_data = []
rows_s = []
cols_s = []

for k in reduced_lv.keys():
    counter = collections.Counter(reduced_lv[k])
    nonzero_data += counter.values()
    rows_s += [lv_bid_to_index[k]]*len(counter.values())
    cols_s += [lv_word_to_index[ck] for ck in counter.keys()]

sparse_mat = sparse.csc_matrix((nonzero_data,(rows_s,cols_s)),shape = (len(lv_bid_to_index),len(lv_word_to_index)))

# %%
dtm_lv = sparse_mat.toarray()

# %%
np.save("temp/lasvegas_dtm",dtm_lv)
